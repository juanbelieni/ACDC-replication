# %%
import transformer_lens as tl
import torch as t
import torch.nn.functional as F
from acdc.TLACDCExperiment import TLACDCCorrespondence
import dataclasses as dc
from typing import Optional
from enum import Enum
from pprint import pprint
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import random

flatten = itertools.chain.from_iterable

# %%
device = t.device("cuda" if t.cuda.is_available() else "cpu")
model = tl.HookedTransformer.from_pretrained("attn-only-2l")
model = model.to(device)

# NOTE. The following lines are present in the code of the official repo,
# but I don't know what it really does.

model.set_use_attn_result(True)     
model.set_use_split_qkv_input(True)
# Out:
# Loaded pretrained model attn-only-2l into HookedTransformer
# Moving model to device:  cuda

# %%
for name, parameters in model.named_parameters():
    print(f"{name}: {parameters.shape}")
# Out:
# embed.W_E: torch.Size([48262, 512])
# pos_embed.W_pos: torch.Size([1024, 512])
# blocks.0.attn.W_Q: torch.Size([8, 512, 64])
# blocks.0.attn.W_O: torch.Size([8, 64, 512])
# blocks.0.attn.b_Q: torch.Size([8, 64])
# blocks.0.attn.b_O: torch.Size([512])
# blocks.0.attn.W_K: torch.Size([8, 512, 64])
# blocks.0.attn.W_V: torch.Size([8, 512, 64])
# blocks.0.attn.b_K: torch.Size([8, 64])
# blocks.0.attn.b_V: torch.Size([8, 64])
# blocks.1.attn.W_Q: torch.Size([8, 512, 64])
# blocks.1.attn.W_O: torch.Size([8, 64, 512])
# blocks.1.attn.b_Q: torch.Size([8, 64])
# blocks.1.attn.b_O: torch.Size([512])
# blocks.1.attn.W_K: torch.Size([8, 512, 64])
# blocks.1.attn.W_V: torch.Size([8, 512, 64])
# blocks.1.attn.b_K: torch.Size([8, 64])
# blocks.1.attn.b_V: torch.Size([8, 64])
# unembed.W_U: torch.Size([512, 48262])
# unembed.b_U: torch.Size([48262])

# %%
# NOTE. Edges from the ACDC package, maybe we should create a method to compare our graph to theirs.

correspondence = TLACDCCorrespondence.setup_from_model(model)
correspondence.edges
# Out:
# OrderedDefaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>()>,
#                    {'blocks.1.hook_resid_post': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.attn.hook_result': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)})})}),
#                     'blocks.1.attn.hook_q': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_k': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_v': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.hook_v_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.attn.hook_result': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
# ...
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.attn.hook_k': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.attn.hook_v': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_v_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})})})

# %%
# NOTE. I got this code from ARENA.

def generate_repeated_tokens(
    model: tl.HookedTransformer,
    seq_len: int,
    num_seq: int = 1
) -> t.Tensor:
    prefix = (t.ones(num_seq, 1) * model.tokenizer.bos_token_id).long()
    rep_tokens_half = t.randint(0, model.cfg.d_vocab, (num_seq, seq_len), dtype=t.int64)
    rep_tokens = t.cat([prefix, rep_tokens_half, rep_tokens_half], dim=-1).to(device)
    return rep_tokens

seq_len = 25
num_seq = 100

dataset = generate_repeated_tokens(model=model, seq_len=seq_len, num_seq=num_seq)[:, :-1]
dataset.shape
# Out:
# torch.Size([100, 50])

# %%
logits, cache = model.run_with_cache(dataset)
for name, values in cache.items():
    print(f"{name}: {values.shape}")
# Out:
# hook_embed: torch.Size([100, 50, 512])
# hook_pos_embed: torch.Size([100, 50, 512])
# blocks.0.hook_resid_pre: torch.Size([100, 50, 512])
# blocks.0.hook_q_input: torch.Size([100, 50, 8, 512])
# blocks.0.hook_k_input: torch.Size([100, 50, 8, 512])
# blocks.0.hook_v_input: torch.Size([100, 50, 8, 512])
# blocks.0.ln1.hook_scale: torch.Size([100, 50, 8, 1])
# blocks.0.ln1.hook_normalized: torch.Size([100, 50, 8, 512])
# blocks.0.attn.hook_q: torch.Size([100, 50, 8, 64])
# blocks.0.attn.hook_k: torch.Size([100, 50, 8, 64])
# blocks.0.attn.hook_v: torch.Size([100, 50, 8, 64])
# blocks.0.attn.hook_attn_scores: torch.Size([100, 8, 50, 50])
# blocks.0.attn.hook_pattern: torch.Size([100, 8, 50, 50])
# blocks.0.attn.hook_z: torch.Size([100, 50, 8, 64])
# blocks.0.attn.hook_result: torch.Size([100, 50, 8, 512])
# blocks.0.hook_attn_out: torch.Size([100, 50, 512])
# blocks.0.hook_resid_post: torch.Size([100, 50, 512])
# blocks.1.hook_resid_pre: torch.Size([100, 50, 512])
# blocks.1.hook_q_input: torch.Size([100, 50, 8, 512])
# blocks.1.hook_k_input: torch.Size([100, 50, 8, 512])
# blocks.1.hook_v_input: torch.Size([100, 50, 8, 512])
# blocks.1.ln1.hook_scale: torch.Size([100, 50, 8, 1])
# blocks.1.ln1.hook_normalized: torch.Size([100, 50, 8, 512])
# blocks.1.attn.hook_q: torch.Size([100, 50, 8, 64])
# blocks.1.attn.hook_k: torch.Size([100, 50, 8, 64])
# blocks.1.attn.hook_v: torch.Size([100, 50, 8, 64])
# blocks.1.attn.hook_attn_scores: torch.Size([100, 8, 50, 50])
# blocks.1.attn.hook_pattern: torch.Size([100, 8, 50, 50])
# blocks.1.attn.hook_z: torch.Size([100, 50, 8, 64])
# blocks.1.attn.hook_result: torch.Size([100, 50, 8, 512])
# blocks.1.hook_attn_out: torch.Size([100, 50, 512])
# blocks.1.hook_resid_post: torch.Size([100, 50, 512])
# ln_final.hook_scale: torch.Size([100, 50, 1])
# ln_final.hook_normalized: torch.Size([100, 50, 512])

# %%
@dc.dataclass(frozen=True)
class TransformerNode:
    hook_name: str
    head_idx: Optional[int] = None

    @property
    def index(self):
        colon = slice(None)
        head_idx = self.head_idx

        if head_idx is not None: return tuple([colon, colon, head_idx, colon])
        else: return tuple([colon, colon, colon])
    
    def __repr__(self):
        head_idx = self.head_idx
        return f"N({self.hook_name}{f'({head_idx})' if head_idx is not None else ''})"

class TransformerEdgeType(Enum):
    ADDITION = 0
    DIRECT_COMPUTATION = 1
    PLACEHOLDER = 2

    def __repr__(self):
        return self.name

def setup_nx_graph_from_model(model: tl.HookedTransformer):
    graph = nx.DiGraph()
    
    n_layers = model.cfg.n_layers
    residual_stream_nodes: list[TransformerNode] = []

    logits_node = TransformerNode(f"blocks.{n_layers-1}.hook_resid_post")

    graph.add_node(logits_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset="logits")
    residual_stream_nodes.append(logits_node)

    for layer_idx in range(model.cfg.n_layers - 1, -1, -1):
        new_residual_stream_nodes: list[TransformerNode] = []

        for head_idx in range(model.cfg.n_heads - 1, -1, -1):
            cur_head_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_result", head_idx)
            graph.add_node(cur_head_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset=f"layer {layer_idx} result")
    
            for residual_stream_node in residual_stream_nodes:
                graph.add_edge(
                    cur_head_node, residual_stream_node,
                    edge_type=TransformerEdgeType.ADDITION,
                )

            for letter in "qkv":
                letter_hook_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_{letter}", head_idx)
                graph.add_node(letter_hook_node, incoming_edge_type=TransformerEdgeType.DIRECT_COMPUTATION, subset=f"layer {layer_idx} letter")

                letter_input_hook_node = TransformerNode(f"blocks.{layer_idx}.hook_{letter}_input", head_idx)
                graph.add_node(letter_input_hook_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset=f"layer {layer_idx} input")

                graph.add_edge(
                    letter_hook_node, cur_head_node,
                    edge_type=TransformerEdgeType.PLACEHOLDER,
                )

                graph.add_edge(
                    letter_input_hook_node, letter_hook_node,
                    edge_type=TransformerEdgeType.DIRECT_COMPUTATION,
                )

                new_residual_stream_nodes.append(letter_input_hook_node)

        residual_stream_nodes.extend(new_residual_stream_nodes)

    token_embed_node = TransformerNode(hook_name="hook_embed")
    pos_embed_node = TransformerNode("hook_pos_embed")

    # NOTE. For now, we will always include the positional embedding node. 

    embed_nodes = [token_embed_node, pos_embed_node]

    for embed_node in embed_nodes:
        graph.add_node(embed_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset="embed")

        for residual_stream_node in residual_stream_nodes:
            graph.add_edge(
                embed_node, residual_stream_node,
                edge_type=TransformerEdgeType.ADDITION
            )

    for u, v, data in graph.edges.data():
        data["present"] = True
        v = graph.nodes[v]
        assert data["edge_type"] == v["incoming_edge_type"]

    return graph

# %%
graph = setup_nx_graph_from_model(model)

plt.figure(figsize=(12, 6))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(graph, pos, node_size=50)
nx.draw_networkx_edges(graph, pos, node_size=50, alpha=0.5)
plt.show()

# %%
# Setup corrupted and online cache

model.reset_hooks()

model.add_hook(
    name = lambda hook_name: any([substring in hook_name for substring in ["hook_result", "hook_pos_embed", "hook_embed"]]),
    hook = lambda z, hook: t.zeros_like(z))

_, corrupted_cache = model.run_with_cache(dataset)
online_cache = dict()

model.reset_hooks()

# %%
def receiver_hook(hook_tensor, hook):
    hook_nodes = [node for node in graph.nodes if node.hook_name == hook.name]
    incoming_edge_types = [graph.nodes[node]['incoming_edge_type'] for node in hook_nodes]
    
    if TransformerEdgeType.DIRECT_COMPUTATION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.DIRECT_COMPUTATION for _ in incoming_edge_types], f"All incoming edges should be the same type not {incoming_edge_types}"
    
        old_z = hook_tensor.clone()
        hook_tensor[:] = corrupted_cache[hook.name]
    
        for receiver in hook_nodes:
            senders = [sender for sender, _, data in graph.in_edges(receiver, data=True) if data["present"]]

            assert len(senders) <= 1, "This is a direct computation, so there should only be one sender node"
            if len(senders) == 0: continue

            hook_tensor[receiver.index] = old_z[receiver.index]
    
    if TransformerEdgeType.ADDITION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.ADDITION for _ in incoming_edge_types], f"All incoming edges should be the same type, not {incoming_edge_types}"
        hook_tensor[:] = corrupted_cache[hook.name]
        
        for receiver in hook_nodes:
            for sender, _, data in graph.in_edges(receiver, data=True):
                if not data["present"]: continue

                assert data["edge_type"] == TransformerEdgeType.ADDITION
            
                hook_tensor[receiver.index] += online_cache[sender.hook_name][sender.index]
                hook_tensor[receiver.index] -= corrupted_cache[sender.hook_name][sender.index]

    return hook_tensor

def sender_hook(hook_tensor, hook):
    online_cache[hook.name] = hook_tensor
    return hook_tensor

# %%
model.reset_hooks()

receiver_hook_names = set([
    node.hook_name
    for node, data in graph.nodes(data=True)
    if data["incoming_edge_type"] != TransformerEdgeType.PLACEHOLDER])

for hook_name in receiver_hook_names:
    model.add_hook(
        name=hook_name,
        hook=receiver_hook)

sender_hook_names = set(flatten([
    [sender.hook_name, receiver.hook_name]
    for sender, receiver, data
    in graph.edges(data=True)
    if data["edge_type"] != TransformerEdgeType.PLACEHOLDER]))

for hook_name in sender_hook_names:
    model.add_hook(
        name=hook_name,
        hook=sender_hook)

# %%
# NOTE. Ratio of sequences that have the associated argmax logit as the correct one.

logits = model(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.6100000143051147

# %%
# NOTE. Just a test, removing random edges.
for sender, receiver, data in graph.edges(data=True):
    data["present"] = True

    if random.random() < 0.01:
        data["present"] = False

logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.5899999737739563

# %%
def kl_divergence(current_logits, corrupted_logits):
    current_dist = t.distributions.Categorical(logits=current_logits)
    corrupted_dist = t.distributions.Categorical(logits=corrupted_logits)
    
    # probs = F.softmax(logits, dim=-1)
    # probs_corrupted = F.softmax(logits_corrupted, dim=-1)

    # kl_div = F.kl_div(probs, probs_corrupted, reduction='none')
    kl_div = t.distributions.kl_divergence(current_dist, corrupted_dist).mean()
    return kl_div.item()

# %%
def pruning(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    # model.reset_hooks()
    topological_sort_nodes = list(nx.topological_sort(graph))
    
    for receiver in reversed(topological_sort_nodes):
        if graph.nodes[receiver]['incoming_edge_type'] == TransformerEdgeType.PLACEHOLDER:
            continue

        out_edges = graph.out_edges(receiver, data=True)

        if len(out_edges) > 0 and all(not data["present"] for _, _, data in out_edges):
            print(f"All out edges from {receiver} are not present, pruning all in edges.")
            for sender, _, data in graph.in_edges(receiver, data=True):
                print(f"Pruned edge from {sender} to {receiver}.")
                data["present"] = False
    
        # Temporarily remove each incoming edge
        for sender, _, data in graph.in_edges(receiver, data=True):
            if data["present"]:
                current_output = model(dataset)[:, -1, :]
                data["present"] = False
                corrupted_output = model(dataset)[:, -1, :]

                # _, corrupted_cache = model.run_with_cache(dataset)
                kl_div = kl_divergence(current_output, corrupted_output)
                
                if kl_div < threshold:
                    print(f"Pruned edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = False
                else:
                    print(f"Kept edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = True

        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

    for receiver in topological_sort_nodes:
        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

# %%
def ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    for _, _, data in graph.edges(data=True):
        data["present"] = True
    
    pruning(graph, model, dataset, corrupted_cache, online_cache, threshold) 

ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.075)
# Out:
# Kept edge from N(blocks.1.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.3514617085456848.
# Kept edge from N(blocks.1.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 4.055453777313232.
# Kept edge from N(blocks.1.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.08316179364919662.
# Kept edge from N(blocks.1.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.10625501722097397.
# Kept edge from N(blocks.1.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.1285400688648224.
# Kept edge from N(blocks.1.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.07576069980859756.
# Kept edge from N(blocks.1.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.09520602971315384.
# Kept edge from N(blocks.1.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.08774259686470032.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.018597478047013283.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 0.019958296790719032.
# Kept edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.10358838737010956.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.026788825169205666.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.03216587007045746.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.013433381915092468.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.022833041846752167.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.013561489060521126.
# Kept edge from N(hook_embed) to N(blocks.1.hook_resid_post) with KL divergence 0.2600421607494354.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_resid_post) with KL divergence 0.031099408864974976.
# Kept edge from N(blocks.1.hook_v_input(0)) to N(blocks.1.attn.hook_v(0)) with KL divergence 0.2712342143058777.
# Kept edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)) with KL divergence 0.08440740406513214.
# Kept edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)) with KL divergence 0.09946248680353165.
# Kept edge from N(blocks.1.hook_v_input(1)) to N(blocks.1.attn.hook_v(1)) with KL divergence 0.22363071143627167.
# Pruned edge from N(blocks.1.hook_k_input(1)) to N(blocks.1.attn.hook_k(1)) with KL divergence 0.05081453174352646.
# All in edges to N(blocks.1.attn.hook_k(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(1)) to N(blocks.1.attn.hook_result(1)).
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)) with KL divergence 0.0.
# All in edges to N(blocks.1.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(1)) to N(blocks.1.attn.hook_result(1)).
# Kept edge from N(blocks.1.hook_v_input(2)) to N(blocks.1.attn.hook_v(2)) with KL divergence 0.19808652997016907.
# Pruned edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)) with KL divergence 0.06142304837703705.
# All in edges to N(blocks.1.attn.hook_k(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(2)) to N(blocks.1.attn.hook_result(2)).
# Pruned edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)) with KL divergence 0.0.
# All in edges to N(blocks.1.attn.hook_q(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(2)) to N(blocks.1.attn.hook_result(2)).
# Kept edge from N(blocks.1.hook_v_input(3)) to N(blocks.1.attn.hook_v(3)) with KL divergence 0.33819010853767395.
# Pruned edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)) with KL divergence 0.047000616788864136.
# All in edges to N(blocks.1.attn.hook_k(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(3)) to N(blocks.1.attn.hook_result(3)).
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)) with KL divergence 0.0.
# All in edges to N(blocks.1.attn.hook_q(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(3)) to N(blocks.1.attn.hook_result(3)).
# Kept edge from N(blocks.1.hook_v_input(4)) to N(blocks.1.attn.hook_v(4)) with KL divergence 0.2840310037136078.
# Pruned edge from N(blocks.1.hook_k_input(4)) to N(blocks.1.attn.hook_k(4)) with KL divergence 0.05854443088173866.
# All in edges to N(blocks.1.attn.hook_k(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(4)) to N(blocks.1.attn.hook_result(4)).
# Pruned edge from N(blocks.1.hook_q_input(4)) to N(blocks.1.attn.hook_q(4)) with KL divergence 0.0.
# All in edges to N(blocks.1.attn.hook_q(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(4)) to N(blocks.1.attn.hook_result(4)).
# Kept edge from N(blocks.1.hook_v_input(5)) to N(blocks.1.attn.hook_v(5)) with KL divergence 0.21588298678398132.
# Kept edge from N(blocks.1.hook_k_input(5)) to N(blocks.1.attn.hook_k(5)) with KL divergence 0.11454330384731293.
# Pruned edge from N(blocks.1.hook_q_input(5)) to N(blocks.1.attn.hook_q(5)) with KL divergence 0.03253692016005516.
# All in edges to N(blocks.1.attn.hook_q(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(5)) to N(blocks.1.attn.hook_result(5)).
# Kept edge from N(blocks.1.hook_v_input(6)) to N(blocks.1.attn.hook_v(6)) with KL divergence 5.843014240264893.
# Kept edge from N(blocks.1.hook_k_input(6)) to N(blocks.1.attn.hook_k(6)) with KL divergence 4.613850116729736.
# Kept edge from N(blocks.1.hook_q_input(6)) to N(blocks.1.attn.hook_q(6)) with KL divergence 4.769960403442383.
# Kept edge from N(blocks.1.hook_v_input(7)) to N(blocks.1.attn.hook_v(7)) with KL divergence 3.890993595123291.
# Kept edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)) with KL divergence 0.1299620270729065.
# Kept edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)) with KL divergence 0.15578588843345642.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.020416652783751488.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.011837461031973362.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.01334181148558855.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.043426621705293655.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.019585546106100082.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.01641818881034851.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.01616949960589409.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.005224109627306461.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(0)) with KL divergence 0.07403617352247238.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(0)) with KL divergence 0.022854123264551163.
# All in edges to N(blocks.1.hook_v_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(0)) to N(blocks.1.attn.hook_v(0)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(0)) with KL divergence -7.276683788859373e-08.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(0)) with KL divergence 8.956883590371945e-08.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(0)) with KL divergence -6.643684002938244e-08.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(0)) with KL divergence 1.959974227361272e-08.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(0)) with KL divergence 1.2830791540352493e-08.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(0)) with KL divergence -3.811975091139175e-08.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(0)) with KL divergence 2.555053235653304e-08.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(0)) with KL divergence -4.8999307722397134e-08.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(0)) with KL divergence 2.6492143589962325e-08.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(0)) with KL divergence 9.97213476239267e-08.
# All in edges to N(blocks.1.hook_k_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0.
# All in edges to N(blocks.1.hook_q_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.008740299381315708.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.006534051615744829.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.004360833205282688.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.01669306494295597.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.010679058730602264.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.011792617850005627.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.006523824762552977.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0032551928889006376.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(1)) with KL divergence 0.040178947150707245.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(1)) with KL divergence 0.017380625009536743.
# All in edges to N(blocks.1.hook_v_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(1)) to N(blocks.1.attn.hook_v(1)).
# All out edges from N(blocks.1.hook_k_input(1)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(1)).
# All in edges to N(blocks.1.hook_k_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(1)) to N(blocks.1.attn.hook_k(1)).
# All out edges from N(blocks.1.hook_q_input(1)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(1)).
# All in edges to N(blocks.1.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.010831021703779697.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.015132338739931583.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.026032162830233574.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.023639816790819168.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.009525731205940247.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.014784946106374264.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.007751593366265297.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.002230612328276038.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(2)) with KL divergence 0.02906075119972229.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(2)) with KL divergence 0.03888537734746933.
# All in edges to N(blocks.1.hook_v_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(2)) to N(blocks.1.attn.hook_v(2)).
# All out edges from N(blocks.1.hook_k_input(2)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(2)).
# All in edges to N(blocks.1.hook_k_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)).
# All out edges from N(blocks.1.hook_q_input(2)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(2)).
# All in edges to N(blocks.1.hook_q_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.014279908500611782.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.011559729464352131.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.02980796806514263.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.045034680515527725.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.02414720505475998.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.04275316745042801.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.010378915816545486.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.002188463695347309.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(3)) with KL divergence 0.03858736529946327.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(3)) with KL divergence 0.03959350660443306.
# All in edges to N(blocks.1.hook_v_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(3)) to N(blocks.1.attn.hook_v(3)).
# All out edges from N(blocks.1.hook_k_input(3)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(3)).
# All in edges to N(blocks.1.hook_k_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)).
# All out edges from N(blocks.1.hook_q_input(3)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(3)).
# All in edges to N(blocks.1.hook_q_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.009756017476320267.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.008312716148793697.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.015433239750564098.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.02650032378733158.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.005495434161275625.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.007409661076962948.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.006070933770388365.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.003890484571456909.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(4)) with KL divergence 0.025524986907839775.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(4)) with KL divergence 0.03709326684474945.
# All in edges to N(blocks.1.hook_v_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(4)) to N(blocks.1.attn.hook_v(4)).
# All out edges from N(blocks.1.hook_k_input(4)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(4)).
# All in edges to N(blocks.1.hook_k_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(4)) to N(blocks.1.attn.hook_k(4)).
# All out edges from N(blocks.1.hook_q_input(4)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(4)).
# All in edges to N(blocks.1.hook_q_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(4)) to N(blocks.1.attn.hook_q(4)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.009303742088377476.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.005052604712545872.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.00496943574398756.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.01725046895444393.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.035990454256534576.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.017344364896416664.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.027181655168533325.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.00475679524242878.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_v_input(5)) with KL divergence 0.01437401957809925.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(5)) with KL divergence 0.037360161542892456.
# All in edges to N(blocks.1.hook_v_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(5)) to N(blocks.1.attn.hook_v(5)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(5)) with KL divergence 9.473274387161723e-10.
# All in edges to N(blocks.1.hook_k_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(5)) to N(blocks.1.attn.hook_k(5)).
# All out edges from N(blocks.1.hook_q_input(5)) are not present, pruning all in edges.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(5)).
# All in edges to N(blocks.1.hook_q_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(5)) to N(blocks.1.attn.hook_q(5)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.037961456924676895.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.02798423171043396.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0396098718047142.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.02339188940823078.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.10103259980678558.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.055737461894750595.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.028599880635738373.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.009806355461478233.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(6)) with KL divergence 1.8186416625976562.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(6)) with KL divergence 0.021412789821624756.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.007960162125527859.
# Kept edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.10929360240697861.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.011100907810032368.
# Kept edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.3775118291378021.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(6)) with KL divergence 1.3318333625793457.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0118968915194273.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.01550417672842741.
# Kept edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.6675875782966614.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(6)) with KL divergence 0.23953795433044434.
# Kept edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(6)) with KL divergence 0.28265875577926636.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.01973552443087101.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.0035118679516017437.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.009462462738156319.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.016214560717344284.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.039460595697164536.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.06816983968019485.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.024063624441623688.
# Kept edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.1949567347764969.
# Kept edge from N(hook_embed) to N(blocks.1.hook_q_input(6)) with KL divergence 1.2946909666061401.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(6)) with KL divergence 0.03595425933599472.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.11347638070583344.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.020515505224466324.
# Kept edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.08565279096364975.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.03687744215130806.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0898929014801979.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0645514652132988.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.025234702974557877.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.005623273551464081.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(7)) with KL divergence 0.09771052747964859.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_v_input(7)) with KL divergence 0.011403302662074566.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.02768819034099579.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.005521373823285103.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0017864475958049297.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.014184395782649517.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.024321140721440315.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0014722368214279413.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.003939421847462654.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.004894176498055458.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(7)) with KL divergence 0.05294983088970184.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_k_input(7)) with KL divergence 0.015884971246123314.
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(hook_pos_embed) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# Kept edge from N(blocks.0.hook_v_input(0)) to N(blocks.0.attn.hook_v(0)) with KL divergence 0.16068491339683533.
# Kept edge from N(blocks.0.hook_k_input(0)) to N(blocks.0.attn.hook_k(0)) with KL divergence 0.15023909509181976.
# Kept edge from N(blocks.0.hook_q_input(0)) to N(blocks.0.attn.hook_q(0)) with KL divergence 0.18689829111099243.
# Pruned edge from N(blocks.0.hook_v_input(1)) to N(blocks.0.attn.hook_v(1)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_v(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_v(1)) to N(blocks.0.attn.hook_result(1)).
# Pruned edge from N(blocks.0.hook_k_input(1)) to N(blocks.0.attn.hook_k(1)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_k(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(1)) to N(blocks.0.attn.hook_result(1)).
# Pruned edge from N(blocks.0.hook_q_input(1)) to N(blocks.0.attn.hook_q(1)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(1)) to N(blocks.0.attn.hook_result(1)).
# Pruned edge from N(blocks.0.hook_v_input(2)) to N(blocks.0.attn.hook_v(2)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_v(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_v(2)) to N(blocks.0.attn.hook_result(2)).
# Pruned edge from N(blocks.0.hook_k_input(2)) to N(blocks.0.attn.hook_k(2)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_k(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(2)) to N(blocks.0.attn.hook_result(2)).
# Pruned edge from N(blocks.0.hook_q_input(2)) to N(blocks.0.attn.hook_q(2)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_q(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(2)) to N(blocks.0.attn.hook_result(2)).
# Kept edge from N(blocks.0.hook_v_input(3)) to N(blocks.0.attn.hook_v(3)) with KL divergence 2.0842103958129883.
# Kept edge from N(blocks.0.hook_k_input(3)) to N(blocks.0.attn.hook_k(3)) with KL divergence 1.8916980028152466.
# Kept edge from N(blocks.0.hook_q_input(3)) to N(blocks.0.attn.hook_q(3)) with KL divergence 2.2837188243865967.
# Kept edge from N(blocks.0.hook_v_input(4)) to N(blocks.0.attn.hook_v(4)) with KL divergence 0.24328964948654175.
# Kept edge from N(blocks.0.hook_k_input(4)) to N(blocks.0.attn.hook_k(4)) with KL divergence 1.260934829711914.
# Pruned edge from N(blocks.0.hook_q_input(4)) to N(blocks.0.attn.hook_q(4)) with KL divergence 0.052455876022577286.
# All in edges to N(blocks.0.attn.hook_q(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(4)) to N(blocks.0.attn.hook_result(4)).
# Kept edge from N(blocks.0.hook_v_input(5)) to N(blocks.0.attn.hook_v(5)) with KL divergence 0.34976813197135925.
# Kept edge from N(blocks.0.hook_k_input(5)) to N(blocks.0.attn.hook_k(5)) with KL divergence 0.41684260964393616.
# Pruned edge from N(blocks.0.hook_q_input(5)) to N(blocks.0.attn.hook_q(5)) with KL divergence 0.00937922764569521.
# All in edges to N(blocks.0.attn.hook_q(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(5)) to N(blocks.0.attn.hook_result(5)).
# Kept edge from N(blocks.0.hook_v_input(6)) to N(blocks.0.attn.hook_v(6)) with KL divergence 0.07698846608400345.
# Pruned edge from N(blocks.0.hook_k_input(6)) to N(blocks.0.attn.hook_k(6)) with KL divergence 0.006885537877678871.
# All in edges to N(blocks.0.attn.hook_k(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(6)) to N(blocks.0.attn.hook_result(6)).
# Pruned edge from N(blocks.0.hook_q_input(6)) to N(blocks.0.attn.hook_q(6)) with KL divergence 0.0.
# All in edges to N(blocks.0.attn.hook_q(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(6)) to N(blocks.0.attn.hook_result(6)).
# Kept edge from N(blocks.0.hook_v_input(7)) to N(blocks.0.attn.hook_v(7)) with KL divergence 0.11259361356496811.
# Kept edge from N(blocks.0.hook_k_input(7)) to N(blocks.0.attn.hook_k(7)) with KL divergence 0.3654199242591858.
# Kept edge from N(blocks.0.hook_q_input(7)) to N(blocks.0.attn.hook_q(7)) with KL divergence 0.21842898428440094.
# Kept edge from N(hook_embed) to N(blocks.0.hook_v_input(0)) with KL divergence 0.3422904908657074.
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(0)) with KL divergence 0.04641405865550041.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(0)) with KL divergence 0.06999822705984116.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(0)) with KL divergence 0.2619698643684387.
# Kept edge from N(hook_embed) to N(blocks.0.hook_q_input(0)) with KL divergence 0.9366416931152344.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(0)) with KL divergence 0.35328608751296997.
# All out edges from N(blocks.0.hook_v_input(1)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(1)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(1)).
# All in edges to N(blocks.0.hook_v_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_v_input(1)) to N(blocks.0.attn.hook_v(1)).
# All out edges from N(blocks.0.hook_k_input(1)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(1)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(1)).
# All in edges to N(blocks.0.hook_k_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(1)) to N(blocks.0.attn.hook_k(1)).
# All out edges from N(blocks.0.hook_q_input(1)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_q_input(1)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(1)).
# All in edges to N(blocks.0.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(1)) to N(blocks.0.attn.hook_q(1)).
# All out edges from N(blocks.0.hook_v_input(2)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(2)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(2)).
# All in edges to N(blocks.0.hook_v_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_v_input(2)) to N(blocks.0.attn.hook_v(2)).
# All out edges from N(blocks.0.hook_k_input(2)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(2)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(2)).
# All in edges to N(blocks.0.hook_k_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(2)) to N(blocks.0.attn.hook_k(2)).
# All out edges from N(blocks.0.hook_q_input(2)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_q_input(2)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(2)).
# All in edges to N(blocks.0.hook_q_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(2)) to N(blocks.0.attn.hook_q(2)).
# Kept edge from N(hook_embed) to N(blocks.0.hook_v_input(3)) with KL divergence 1.6002733707427979.
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(3)) with KL divergence 0.03161930665373802.
# Kept edge from N(hook_embed) to N(blocks.0.hook_k_input(3)) with KL divergence 0.1874605119228363.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(3)) with KL divergence 1.8343533277511597.
# Kept edge from N(hook_embed) to N(blocks.0.hook_q_input(3)) with KL divergence 0.1728631556034088.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(3)) with KL divergence 2.142049789428711.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(4)) with KL divergence 0.0015596462180837989.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(4)) with KL divergence 0.12451774626970291.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(4)) with KL divergence 0.0006763261626474559.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(4)) with KL divergence 2.0646884441375732.
# All out edges from N(blocks.0.hook_q_input(4)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_q_input(4)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(4)).
# All in edges to N(blocks.0.hook_q_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(4)) to N(blocks.0.attn.hook_q(4)).
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(5)) with KL divergence 0.00854935497045517.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(5)) with KL divergence 0.3013128340244293.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(5)) with KL divergence 1.1197275995300515e-08.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(5)) with KL divergence 0.30367550253868103.
# All out edges from N(blocks.0.hook_q_input(5)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_q_input(5)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(5)).
# All in edges to N(blocks.0.hook_q_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(5)) to N(blocks.0.attn.hook_q(5)).
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(6)) with KL divergence 0.0019442921038717031.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(6)) with KL divergence 0.10800883919000626.
# All out edges from N(blocks.0.hook_k_input(6)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_k_input(6)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(6)).
# All in edges to N(blocks.0.hook_k_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(6)) to N(blocks.0.attn.hook_k(6)).
# All out edges from N(blocks.0.hook_q_input(6)) are not present, pruning all in edges.
# Pruned edge from N(hook_embed) to N(blocks.0.hook_q_input(6)).
# Pruned edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(6)).
# All in edges to N(blocks.0.hook_q_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(6)) to N(blocks.0.attn.hook_q(6)).
# Pruned edge from N(hook_embed) to N(blocks.0.hook_v_input(7)) with KL divergence 0.005403699818998575.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_v_input(7)) with KL divergence 0.13089561462402344.
# Kept edge from N(hook_embed) to N(blocks.0.hook_k_input(7)) with KL divergence 0.14787554740905762.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_k_input(7)) with KL divergence 0.281110018491745.
# Kept edge from N(hook_embed) to N(blocks.0.hook_q_input(7)) with KL divergence 0.1409105807542801.
# Kept edge from N(hook_pos_embed) to N(blocks.0.hook_q_input(7)) with KL divergence 0.11938663572072983.
# All in edges to N(blocks.0.hook_q_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(6)) to N(blocks.0.attn.hook_q(6)).
# All in edges to N(blocks.0.hook_k_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(6)) to N(blocks.0.attn.hook_k(6)).
# All in edges to N(blocks.0.hook_q_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(5)) to N(blocks.0.attn.hook_q(5)).
# All in edges to N(blocks.0.hook_q_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(4)) to N(blocks.0.attn.hook_q(4)).
# All in edges to N(blocks.0.hook_q_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(2)) to N(blocks.0.attn.hook_q(2)).
# All in edges to N(blocks.0.hook_k_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(2)) to N(blocks.0.attn.hook_k(2)).
# All in edges to N(blocks.0.hook_v_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_v_input(2)) to N(blocks.0.attn.hook_v(2)).
# All in edges to N(blocks.0.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_q_input(1)) to N(blocks.0.attn.hook_q(1)).
# All in edges to N(blocks.0.hook_k_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_k_input(1)) to N(blocks.0.attn.hook_k(1)).
# All in edges to N(blocks.0.hook_v_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.hook_v_input(1)) to N(blocks.0.attn.hook_v(1)).
# All in edges to N(blocks.0.attn.hook_q(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(6)) to N(blocks.0.attn.hook_result(6)).
# All in edges to N(blocks.0.attn.hook_k(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(6)) to N(blocks.0.attn.hook_result(6)).
# All in edges to N(blocks.0.attn.hook_q(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(5)) to N(blocks.0.attn.hook_result(5)).
# All in edges to N(blocks.0.attn.hook_q(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(4)) to N(blocks.0.attn.hook_result(4)).
# All in edges to N(blocks.0.attn.hook_q(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(2)) to N(blocks.0.attn.hook_result(2)).
# All in edges to N(blocks.0.attn.hook_k(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(2)) to N(blocks.0.attn.hook_result(2)).
# All in edges to N(blocks.0.attn.hook_v(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_v(2)) to N(blocks.0.attn.hook_result(2)).
# All in edges to N(blocks.0.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_q(1)) to N(blocks.0.attn.hook_result(1)).
# All in edges to N(blocks.0.attn.hook_k(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_k(1)) to N(blocks.0.attn.hook_result(1)).
# All in edges to N(blocks.0.attn.hook_v(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_v(1)) to N(blocks.0.attn.hook_result(1)).
# All in edges to N(blocks.0.attn.hook_result(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# All in edges to N(blocks.1.hook_q_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(5)) to N(blocks.1.attn.hook_q(5)).
# All in edges to N(blocks.1.hook_k_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(5)) to N(blocks.1.attn.hook_k(5)).
# All in edges to N(blocks.1.hook_v_input(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(5)) to N(blocks.1.attn.hook_v(5)).
# All in edges to N(blocks.1.hook_q_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(4)) to N(blocks.1.attn.hook_q(4)).
# All in edges to N(blocks.1.hook_k_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(4)) to N(blocks.1.attn.hook_k(4)).
# All in edges to N(blocks.1.hook_v_input(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(4)) to N(blocks.1.attn.hook_v(4)).
# All in edges to N(blocks.1.hook_q_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)).
# All in edges to N(blocks.1.hook_k_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)).
# All in edges to N(blocks.1.hook_v_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(3)) to N(blocks.1.attn.hook_v(3)).
# All in edges to N(blocks.1.hook_q_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)).
# All in edges to N(blocks.1.hook_k_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)).
# All in edges to N(blocks.1.hook_v_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(2)) to N(blocks.1.attn.hook_v(2)).
# All in edges to N(blocks.1.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)).
# All in edges to N(blocks.1.hook_k_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(1)) to N(blocks.1.attn.hook_k(1)).
# All in edges to N(blocks.1.hook_v_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(1)) to N(blocks.1.attn.hook_v(1)).
# All in edges to N(blocks.1.hook_q_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)).
# All in edges to N(blocks.1.hook_k_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)).
# All in edges to N(blocks.1.hook_v_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_v_input(0)) to N(blocks.1.attn.hook_v(0)).
# All in edges to N(blocks.1.attn.hook_q(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_k(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_q(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(5)) to N(blocks.1.attn.hook_result(5)).
# All in edges to N(blocks.1.attn.hook_k(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(5)) to N(blocks.1.attn.hook_result(5)).
# All in edges to N(blocks.1.attn.hook_v(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(5)) to N(blocks.1.attn.hook_result(5)).
# All in edges to N(blocks.1.attn.hook_q(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(4)) to N(blocks.1.attn.hook_result(4)).
# All in edges to N(blocks.1.attn.hook_k(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(4)) to N(blocks.1.attn.hook_result(4)).
# All in edges to N(blocks.1.attn.hook_v(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(4)) to N(blocks.1.attn.hook_result(4)).
# All in edges to N(blocks.1.attn.hook_q(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_k(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_v(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_q(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(2)) to N(blocks.1.attn.hook_result(2)).
# All in edges to N(blocks.1.attn.hook_k(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(2)) to N(blocks.1.attn.hook_result(2)).
# All in edges to N(blocks.1.attn.hook_v(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(2)) to N(blocks.1.attn.hook_result(2)).
# All in edges to N(blocks.1.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(1)) to N(blocks.1.attn.hook_result(1)).
# All in edges to N(blocks.1.attn.hook_k(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(1)) to N(blocks.1.attn.hook_result(1)).
# All in edges to N(blocks.1.attn.hook_v(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(1)) to N(blocks.1.attn.hook_result(1)).
# All in edges to N(blocks.1.attn.hook_q(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(0)) to N(blocks.1.attn.hook_result(0)).
# All in edges to N(blocks.1.attn.hook_k(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(0)) to N(blocks.1.attn.hook_result(0)).
# All in edges to N(blocks.1.attn.hook_v(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_v(0)) to N(blocks.1.attn.hook_result(0)).
# All in edges to N(blocks.1.attn.hook_result(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(5)) to N(blocks.1.hook_resid_post).
# All in edges to N(blocks.1.attn.hook_result(4)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(4)) to N(blocks.1.hook_resid_post).
# All in edges to N(blocks.1.attn.hook_result(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(3)) to N(blocks.1.hook_resid_post).
# All in edges to N(blocks.1.attn.hook_result(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(2)) to N(blocks.1.hook_resid_post).
# All in edges to N(blocks.1.attn.hook_result(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(1)) to N(blocks.1.hook_resid_post).
# All in edges to N(blocks.1.attn.hook_result(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_result(0)) to N(blocks.1.hook_resid_post).

# %%
edges_present = [data['present'] for _, _, data in graph.edges(data=True)]
nodes_present = [
    len(out_edges := graph.out_edges(node, data=True)) == 0
    or any(data['present'] for _, _, data in out_edges)
    for node in graph.nodes]

plt.figure(figsize=(12, 6))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(
    graph,
    pos,
    node_size=50,
    alpha=[1 if present else 0.1 for present in nodes_present],
    node_color=["blue" if present else "red" for present in nodes_present])
nx.draw_networkx_edges(
    graph,
    pos,
    node_size=50,
    alpha=[0.5 if present else 0.1 for present in edges_present],
    edge_color=["black" if present else "red" for present in edges_present])
plt.show()

# %%
logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.38999998569488525
