# %%
import transformer_lens as tl
import torch as t
import torch.nn.functional as F
#from acdc.TLACDCExperiment import TLACDCCorrespondence
import dataclasses as dc
from typing import Optional
from enum import Enum
from pprint import pprint
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import random

flatten = itertools.chain.from_iterable

# %%
device = t.device("cuda" if t.cuda.is_available() else t.device("mps"))

cfg = tl.HookedTransformerConfig(
    d_model=768,
    d_head=64,
    n_heads=12,
    n_layers=2,
    n_ctx=2048,
    d_vocab=50278,
    attention_dir="causal",
    attn_only=True, # defaults to False
    tokenizer_name="EleutherAI/gpt-neox-20b", 
    seed=398,
    use_attn_result=True,
    use_split_qkv_input=True,
    normalization_type=None, # defaults to "LN", i.e. layernorm with weights & biases
    positional_embedding_type="shortformer"
)

from huggingface_hub import hf_hub_download

REPO_ID = "callummcdougall/attn_only_2L_half"
FILENAME = "attn_only_2L_half.pth"

weights_path = hf_hub_download(repo_id=REPO_ID, filename=FILENAME)
print(weights_path)

model = tl.HookedTransformer(cfg).to(device)
pretrained_weights = t.load(weights_path, map_location=device)
model.load_state_dict(pretrained_weights)

# model = tl.HookedTransformer.from_pretrained("attn-only-2l")
# model = model.to(device)

# NOTE. The following lines are present in the code of the official repo,
# but I don't know what it really does.

# model.set_use_attn_result(True)     
# model.set_use_split_qkv_input(True)
# Out:
# /Users/anaerthal/.cache/huggingface/hub/models--callummcdougall--attn_only_2L_half/snapshots/3a3d92c6d6491233925c2649582128538a16843a/attn_only_2L_half.pth
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Moving model to device:  mps
# <All keys matched successfully>

# %%
for name, parameters in model.named_parameters():
    print(f"{name}: {parameters.shape}")
# Out:
# embed.W_E: torch.Size([50278, 768])
# pos_embed.W_pos: torch.Size([2048, 768])
# blocks.0.attn.W_Q: torch.Size([12, 768, 64])
# blocks.0.attn.W_O: torch.Size([12, 64, 768])
# blocks.0.attn.b_Q: torch.Size([12, 64])
# blocks.0.attn.b_O: torch.Size([768])
# blocks.0.attn.W_K: torch.Size([12, 768, 64])
# blocks.0.attn.W_V: torch.Size([12, 768, 64])
# blocks.0.attn.b_K: torch.Size([12, 64])
# blocks.0.attn.b_V: torch.Size([12, 64])
# blocks.1.attn.W_Q: torch.Size([12, 768, 64])
# blocks.1.attn.W_O: torch.Size([12, 64, 768])
# blocks.1.attn.b_Q: torch.Size([12, 64])
# blocks.1.attn.b_O: torch.Size([768])
# blocks.1.attn.W_K: torch.Size([12, 768, 64])
# blocks.1.attn.W_V: torch.Size([12, 768, 64])
# blocks.1.attn.b_K: torch.Size([12, 64])
# blocks.1.attn.b_V: torch.Size([12, 64])
# unembed.W_U: torch.Size([768, 50278])
# unembed.b_U: torch.Size([50278])

# %%
# NOTE. Edges from the ACDC package, maybe we should create a method to compare our graph to theirs.

# correspondence = TLACDCCorrespondence.setup_from_model(model)
# correspondence.edges

# %%
# NOTE. I got this code from ARENA.

def generate_repeated_tokens(
    model: tl.HookedTransformer,
    seq_len: int,
    num_seq: int = 1
) -> t.Tensor:
    prefix = (t.ones(num_seq, 1) * model.tokenizer.bos_token_id).long()
    rep_tokens_half = t.randint(0, model.cfg.d_vocab, (num_seq, seq_len), dtype=t.int64)
    rep_tokens = t.cat([prefix, rep_tokens_half, rep_tokens_half], dim=-1).to(device)
    return rep_tokens

seq_len = 30
num_seq = 25

dataset = generate_repeated_tokens(model=model, seq_len=seq_len, num_seq=num_seq)[:, :-1]
dataset.shape
# Out:
# torch.Size([25, 60])

# %%
logits, cache = model.run_with_cache(dataset)
for name, values in cache.items():
    print(f"{name}: {values.shape}")
# Out:
# hook_embed: torch.Size([25, 60, 768])
# hook_pos_embed: torch.Size([25, 60, 768])
# blocks.0.hook_resid_pre: torch.Size([25, 60, 768])
# blocks.0.hook_q_input: torch.Size([25, 60, 12, 768])
# blocks.0.hook_k_input: torch.Size([25, 60, 12, 768])
# blocks.0.hook_v_input: torch.Size([25, 60, 12, 768])
# blocks.0.attn.hook_q: torch.Size([25, 60, 12, 64])
# blocks.0.attn.hook_k: torch.Size([25, 60, 12, 64])
# blocks.0.attn.hook_v: torch.Size([25, 60, 12, 64])
# blocks.0.attn.hook_attn_scores: torch.Size([25, 12, 60, 60])
# blocks.0.attn.hook_pattern: torch.Size([25, 12, 60, 60])
# blocks.0.attn.hook_z: torch.Size([25, 60, 12, 64])
# blocks.0.attn.hook_result: torch.Size([25, 60, 12, 768])
# blocks.0.hook_attn_out: torch.Size([25, 60, 768])
# blocks.0.hook_resid_post: torch.Size([25, 60, 768])
# blocks.1.hook_resid_pre: torch.Size([25, 60, 768])
# blocks.1.hook_q_input: torch.Size([25, 60, 12, 768])
# blocks.1.hook_k_input: torch.Size([25, 60, 12, 768])
# blocks.1.hook_v_input: torch.Size([25, 60, 12, 768])
# blocks.1.attn.hook_q: torch.Size([25, 60, 12, 64])
# blocks.1.attn.hook_k: torch.Size([25, 60, 12, 64])
# blocks.1.attn.hook_v: torch.Size([25, 60, 12, 64])
# blocks.1.attn.hook_attn_scores: torch.Size([25, 12, 60, 60])
# blocks.1.attn.hook_pattern: torch.Size([25, 12, 60, 60])
# blocks.1.attn.hook_z: torch.Size([25, 60, 12, 64])
# blocks.1.attn.hook_result: torch.Size([25, 60, 12, 768])
# blocks.1.hook_attn_out: torch.Size([25, 60, 768])
# blocks.1.hook_resid_post: torch.Size([25, 60, 768])

# %%
@dc.dataclass(frozen=True)
class TransformerNode:
    hook_name: str
    head_idx: Optional[int] = None

    @property
    def index(self):
        colon = slice(None)
        head_idx = self.head_idx

        if head_idx is not None: return tuple([colon, colon, head_idx, colon])
        else: return tuple([colon, colon, colon])
    
    def __repr__(self):
        head_idx = self.head_idx
        return f"N({self.hook_name}{f'({head_idx})' if head_idx is not None else ''})"

class TransformerEdgeType(Enum):
    ADDITION = 0
    DIRECT_COMPUTATION = 1
    PLACEHOLDER = 2

    def __repr__(self):
        return self.name

def setup_nx_graph_from_model(model: tl.HookedTransformer):
    graph = nx.DiGraph()
    
    n_layers = model.cfg.n_layers
    residual_stream_nodes: list[TransformerNode] = []

    logits_node = TransformerNode(f"blocks.{n_layers-1}.hook_resid_post")

    graph.add_node(logits_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset="logits")
    residual_stream_nodes.append(logits_node)

    for layer_idx in range(model.cfg.n_layers - 1, -1, -1):
        new_residual_stream_nodes: list[TransformerNode] = []

        for head_idx in range(model.cfg.n_heads - 1, -1, -1):
            cur_head_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_result", head_idx)
            graph.add_node(cur_head_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset=f"layer {layer_idx} result")
    
            for residual_stream_node in residual_stream_nodes:
                graph.add_edge(
                    cur_head_node, residual_stream_node,
                    edge_type=TransformerEdgeType.ADDITION,
                )

            for letter in "qkv":
                letter_hook_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_{letter}", head_idx)
                graph.add_node(letter_hook_node, incoming_edge_type=TransformerEdgeType.DIRECT_COMPUTATION, subset=f"layer {layer_idx} letter")

                letter_input_hook_node = TransformerNode(f"blocks.{layer_idx}.hook_{letter}_input", head_idx)
                graph.add_node(letter_input_hook_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset=f"layer {layer_idx} input")

                graph.add_edge(
                    letter_hook_node, cur_head_node,
                    edge_type=TransformerEdgeType.PLACEHOLDER,
                )

                graph.add_edge(
                    letter_input_hook_node, letter_hook_node,
                    edge_type=TransformerEdgeType.DIRECT_COMPUTATION,
                )

                new_residual_stream_nodes.append(letter_input_hook_node)

        residual_stream_nodes.extend(new_residual_stream_nodes)

    token_embed_node = TransformerNode(hook_name="hook_embed")
    # pos_embed_node = TransformerNode("hook_pos_embed")

    # NOTE. For now, we will always include the positional embedding node. 

    embed_nodes = [token_embed_node]#, pos_embed_node]

    for embed_node in embed_nodes:
        graph.add_node(embed_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset="embed")

        for residual_stream_node in residual_stream_nodes:
            graph.add_edge(
                embed_node, residual_stream_node,
                edge_type=TransformerEdgeType.ADDITION
            )

    for u, v, data in graph.edges.data():
        data["present"] = True
        v = graph.nodes[v]
        assert data["edge_type"] == v["incoming_edge_type"]

    # Create node labels based on the node attributes
    labels = {}
    for node in graph.nodes:
        if 'hook_q_input' in node.hook_name:
            labels[node] = 'Qi'
        elif 'hook_k_input' in node.hook_name:
            labels[node] = 'Ki'
        elif 'hook_v_input' in node.hook_name:
            labels[node] = 'Vi'
        elif 'attn.hook_q' in node.hook_name:
            labels[node] = 'Q'
        elif 'attn.hook_k' in node.hook_name:
            labels[node] = 'K'
        elif 'attn.hook_v' in node.hook_name:
            labels[node] = 'V'
        elif 'hook_resid_post' in node.hook_name:
            labels[node] = 'O'
        elif 'attn.hook_result' in node.hook_name:
            labels[node] = 'H'
        elif 'hook_embed' in node.hook_name:
            labels[node] = 'E'
        else:
            labels[node] = node.hook_name

    return graph, labels

# %%
graph, labels = setup_nx_graph_from_model(model)

plt.figure(figsize=(12, 8))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(graph, pos, node_size=80, node_color='darkblue')
nx.draw_networkx_edges(graph, pos, node_size=80, alpha=0.5, edge_color='black')
nx.draw_networkx_labels(graph, pos, labels=labels, font_size=8, font_color='white')
plt.show()

# %%
# Setup corrupted and online cache

model.reset_hooks()

model.add_hook(
    name = lambda hook_name: any([substring in hook_name for substring in ["hook_result", "hook_pos_embed", "hook_embed"]]),
    hook = lambda z, hook: t.zeros_like(z))

_, corrupted_cache = model.run_with_cache(dataset)
online_cache = dict()

model.reset_hooks()

# %%
def receiver_hook(hook_tensor, hook):
    hook_nodes = [node for node in graph.nodes if node.hook_name == hook.name]
    incoming_edge_types = [graph.nodes[node]['incoming_edge_type'] for node in hook_nodes]
    
    if TransformerEdgeType.DIRECT_COMPUTATION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.DIRECT_COMPUTATION for _ in incoming_edge_types], f"All incoming edges should be the same type not {incoming_edge_types}"
    
        old_z = hook_tensor.clone()
        hook_tensor[:] = corrupted_cache[hook.name]
    
        for receiver in hook_nodes:
            senders = [sender for sender, _, data in graph.in_edges(receiver, data=True) if data["present"]]

            assert len(senders) <= 1, "This is a direct computation, so there should only be one sender node"
            if len(senders) == 0: continue

            hook_tensor[receiver.index] = old_z[receiver.index]

    
    if TransformerEdgeType.ADDITION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.ADDITION for _ in incoming_edge_types], f"All incoming edges should be the same type, not {incoming_edge_types}"
        hook_tensor[:] = corrupted_cache[hook.name]
        
        for receiver in hook_nodes:
            for sender, _, data in graph.in_edges(receiver, data=True):
                if not data["present"]:
                    continue

                assert data["edge_type"] == TransformerEdgeType.ADDITION
            
                hook_tensor[receiver.index] += online_cache[sender.hook_name][sender.index]
                hook_tensor[receiver.index] -= corrupted_cache[sender.hook_name][sender.index]
    
    return hook_tensor

def sender_hook(hook_tensor, hook):
    online_cache[hook.name] = hook_tensor
    return hook_tensor

# %%
model.reset_hooks()

receiver_hook_names = set([
    node.hook_name
    for node, data in graph.nodes(data=True)
    if data["incoming_edge_type"] != TransformerEdgeType.PLACEHOLDER])

for hook_name in receiver_hook_names:
    model.add_hook(
        name=hook_name,
        hook=receiver_hook)

sender_hook_names = set(flatten([
    [sender.hook_name, receiver.hook_name]
    for sender, receiver, data
    in graph.edges(data=True)
    if data["edge_type"] != TransformerEdgeType.PLACEHOLDER]))

for hook_name in sender_hook_names:
    model.add_hook(
        name=hook_name,
        hook=sender_hook)

# %%
graph[TransformerNode("blocks.1.attn.hook_result", 0)][TransformerNode("blocks.1.hook_resid_post")]["present"] = True

# %%
# NOTE. Ratio of sequences that have the associated argmax logit as the correct one.

logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.5600000023841858

# %%
# NOTE. Just a test, removing random edges.
for sender, receiver, data in graph.edges(data=True):
    data["present"] = True

    if random.random() < 0.01:
        data["present"] = False

logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.5600000023841858

# %%
def kl_divergence(current_logits, corrupted_logits):
    current_dist = t.distributions.Categorical(logits=current_logits)
    corrupted_dist = t.distributions.Categorical(logits=corrupted_logits)

    kl_div = t.distributions.kl_divergence(current_dist, corrupted_dist).mean()
    return kl_div.item()

# %%
def pruning(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    # model.reset_hooks()
    topological_sort_nodes = list(nx.topological_sort(graph))
    
    for receiver in reversed(topological_sort_nodes):
        if graph.nodes[receiver]['incoming_edge_type'] == TransformerEdgeType.PLACEHOLDER:
            continue

        out_edges = graph.out_edges(receiver, data=True)

        if len(out_edges) > 0 and all(not data["present"] for _, _, data in out_edges):
            print(f"All out edges from {receiver} are not present, pruning all in edges.")
            for sender, _, data in graph.in_edges(receiver, data=True):
                print(f"Pruned edge from {sender} to {receiver}.")
                data["present"] = False
    
        # Temporarily remove each incoming edge
        for sender, _, data in graph.in_edges(receiver, data=True):
            if data["present"]:
                current_output = model(dataset)[:, -1, :]
                data["present"] = False
                corrupted_output = model(dataset)[:, -1, :]

                # _, corrupted_cache = model.run_with_cache(dataset)
                kl_div = kl_divergence(current_output, corrupted_output)
                
                if kl_div < threshold:
                    print(f"Pruned edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = False
                else:
                    print(f"Kept edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = True

        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

    for receiver in topological_sort_nodes:
        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

# %%
def ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    for _, _, data in graph.edges(data=True):
        data["present"] = True
    
    pruning(graph, model, dataset, corrupted_cache, online_cache, threshold) 

ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01)
# Out:
# Kept edge from N(blocks.1.attn.hook_result(11)) to N(blocks.1.hook_resid_post) with KL divergence 3.3674206733703613.
# Kept edge from N(blocks.1.attn.hook_result(10)) to N(blocks.1.hook_resid_post) with KL divergence 1.638169527053833.
# Kept edge from N(blocks.1.attn.hook_result(9)) to N(blocks.1.hook_resid_post) with KL divergence 0.07883680611848831.
# Kept edge from N(blocks.1.attn.hook_result(8)) to N(blocks.1.hook_resid_post) with KL divergence 0.09778179228305817.
# Kept edge from N(blocks.1.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.06755688786506653.
# Kept edge from N(blocks.1.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 0.18414095044136047.
# Kept edge from N(blocks.1.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.15428464114665985.
# Kept edge from N(blocks.1.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.9260380268096924.
# Kept edge from N(blocks.1.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.11266440898180008.
# Kept edge from N(blocks.1.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.10246685147285461.
# Kept edge from N(blocks.1.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.09685487300157547.
# Kept edge from N(blocks.1.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.10049084573984146.
# Kept edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_resid_post) with KL divergence 0.09258029609918594.
# Kept edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_resid_post) with KL divergence 0.02122497744858265.
# Kept edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_resid_post) with KL divergence 0.03574582189321518.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_resid_post) with KL divergence 0.0072553870268166065.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.03475073724985123.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 0.007752681616693735.
# Kept edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.010723735205829144.
# Kept edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.016954569146037102.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.07681658118963242.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.009481004439294338.
# Kept edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.02026781067252159.
# Kept edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.01114220917224884.
# Kept edge from N(hook_embed) to N(blocks.1.hook_resid_post) with KL divergence 0.19333459436893463.
# Kept edge from N(blocks.1.hook_v_input(0)) to N(blocks.1.attn.hook_v(0)) with KL divergence 0.09969978034496307.
# Kept edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)) with KL divergence 0.30646684765815735.
# Kept edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)) with KL divergence 0.30646684765815735.
# Kept edge from N(blocks.1.hook_v_input(1)) to N(blocks.1.attn.hook_v(1)) with KL divergence 0.09451644867658615.
# Kept edge from N(blocks.1.hook_k_input(1)) to N(blocks.1.attn.hook_k(1)) with KL divergence 0.04377087950706482.
# Kept edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)) with KL divergence 0.04377087950706482.
# Kept edge from N(blocks.1.hook_v_input(2)) to N(blocks.1.attn.hook_v(2)) with KL divergence 0.09972833096981049.
# Kept edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)) with KL divergence 0.28408369421958923.
# Kept edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)) with KL divergence 0.28408369421958923.
# Kept edge from N(blocks.1.hook_v_input(3)) to N(blocks.1.attn.hook_v(3)) with KL divergence 0.10680385679006577.
# Kept edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)) with KL divergence 0.06660336256027222.
# Kept edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)) with KL divergence 0.06660336256027222.
# Kept edge from N(blocks.1.hook_v_input(4)) to N(blocks.1.attn.hook_v(4)) with KL divergence 0.9273657202720642.
# Kept edge from N(blocks.1.hook_k_input(4)) to N(blocks.1.attn.hook_k(4)) with KL divergence 0.9136130809783936.
# Kept edge from N(blocks.1.hook_q_input(4)) to N(blocks.1.attn.hook_q(4)) with KL divergence 0.9136130809783936.
# Kept edge from N(blocks.1.hook_v_input(5)) to N(blocks.1.attn.hook_v(5)) with KL divergence 0.15002942085266113.
# Kept edge from N(blocks.1.hook_k_input(5)) to N(blocks.1.attn.hook_k(5)) with KL divergence 0.17128045856952667.
# Kept edge from N(blocks.1.hook_q_input(5)) to N(blocks.1.attn.hook_q(5)) with KL divergence 0.17128045856952667.
# Kept edge from N(blocks.1.hook_v_input(6)) to N(blocks.1.attn.hook_v(6)) with KL divergence 0.18824462592601776.
# Kept edge from N(blocks.1.hook_k_input(6)) to N(blocks.1.attn.hook_k(6)) with KL divergence 0.12913699448108673.
# Kept edge from N(blocks.1.hook_q_input(6)) to N(blocks.1.attn.hook_q(6)) with KL divergence 0.12913699448108673.
# Kept edge from N(blocks.1.hook_v_input(7)) to N(blocks.1.attn.hook_v(7)) with KL divergence 0.06559956818819046.
# Kept edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)) with KL divergence 0.030334915965795517.
# Kept edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)) with KL divergence 0.030334915965795517.
# Kept edge from N(blocks.1.hook_v_input(8)) to N(blocks.1.attn.hook_v(8)) with KL divergence 0.10116321593523026.
# Kept edge from N(blocks.1.hook_k_input(8)) to N(blocks.1.attn.hook_k(8)) with KL divergence 0.04160517454147339.
# Kept edge from N(blocks.1.hook_q_input(8)) to N(blocks.1.attn.hook_q(8)) with KL divergence 0.04160517454147339.
# Kept edge from N(blocks.1.hook_v_input(9)) to N(blocks.1.attn.hook_v(9)) with KL divergence 0.07828188687562943.
# Kept edge from N(blocks.1.hook_k_input(9)) to N(blocks.1.attn.hook_k(9)) with KL divergence 0.0423097088932991.
# Kept edge from N(blocks.1.hook_q_input(9)) to N(blocks.1.attn.hook_q(9)) with KL divergence 0.0423097088932991.
# Kept edge from N(blocks.1.hook_v_input(10)) to N(blocks.1.attn.hook_v(10)) with KL divergence 1.648972749710083.
# Kept edge from N(blocks.1.hook_k_input(10)) to N(blocks.1.attn.hook_k(10)) with KL divergence 1.649870753288269.

# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0001645741140237078.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0006525043863803148.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00030199025059118867.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00028695736546069384.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0008879640372470021.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0001816331932786852.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00011177963460795581.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00013954986934550107.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0001271896908292547.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0004958228673785925.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(7)) with KL divergence 8.074261131696403e-05.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(7)) with KL divergence 0.007490978110581636.
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.005071530118584633.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0026713269762694836.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0023025020491331816.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0033566593192517757.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0023257459979504347.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0014767221873626113.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0031851734966039658.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0016682996647432446.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0072496733628213406.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.001475138938985765.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0021524247713387012.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0014677130384370685.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(8)) with KL divergence 0.021920450031757355.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0009850419592112303.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00016624273848719895.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00038534749182872474.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0006694039329886436.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00038012495497241616.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0001675212406553328.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00033457635436207056.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00012661144137382507.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00021366369037423283.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(8)) with KL divergence 7.82458737376146e-05.
# ...
# All in edges to N(blocks.0.attn.hook_result(5)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.1.hook_q_input(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(11)) to N(blocks.1.attn.hook_q(11)).
# All in edges to N(blocks.1.hook_q_input(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(9)) to N(blocks.1.attn.hook_q(9)).
# All in edges to N(blocks.1.hook_q_input(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(8)) to N(blocks.1.attn.hook_q(8)).
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# All in edges to N(blocks.1.hook_q_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)).
# All in edges to N(blocks.1.hook_q_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)).
# All in edges to N(blocks.1.hook_k_input(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)).
# All in edges to N(blocks.1.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)).
# All in edges to N(blocks.1.hook_q_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)).
# All in edges to N(blocks.1.hook_k_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)).
# All in edges to N(blocks.1.attn.hook_q(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(11)) to N(blocks.1.attn.hook_result(11)).
# All in edges to N(blocks.1.attn.hook_q(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(9)) to N(blocks.1.attn.hook_result(9)).
# All in edges to N(blocks.1.attn.hook_q(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(8)) to N(blocks.1.attn.hook_result(8)).
# All in edges to N(blocks.1.attn.hook_q(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_k(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_q(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_q(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(2)) to N(blocks.1.attn.hook_result(2)).
# All in edges to N(blocks.1.attn.hook_k(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(2)) to N(blocks.1.attn.hook_result(2)).
# All in edges to N(blocks.1.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(1)) to N(blocks.1.attn.hook_result(1)).
# All in edges to N(blocks.1.attn.hook_q(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(0)) to N(blocks.1.attn.hook_result(0)).
# All in edges to N(blocks.1.attn.hook_k(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(0)) to N(blocks.1.attn.hook_result(0)).

# %%
edges_present = [data['present'] for _, _, data in graph.edges(data=True)]
nodes_present = [
    len(out_edges := graph.out_edges(node, data=True)) == 0
    or any(data['present'] for _, _, data in out_edges)
    for node in graph.nodes]

plt.figure(figsize=(12, 8))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(
    graph,
    pos,
    node_size=50,
    alpha=[1 if present else 0.1 for present in nodes_present],
    node_color=["blue" if present else "red" for present in nodes_present])
nx.draw_networkx_edges(
    graph,
    pos,
    node_size=50,
    alpha=[0.5 if present else 0.1 for present in edges_present],
    edge_color=["black" if present else "red" for present in edges_present])
nx.draw_networkx_labels(graph, pos, labels=labels, font_size=8, font_color='white')
plt.show()

# %%
logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.0
