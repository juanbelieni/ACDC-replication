# %%
import transformer_lens as tl
import torch as t
from acdc.TLACDCExperiment import TLACDCCorrespondence
import dataclasses as dc
from typing import Optional
from enum import Enum
from pprint import pprint
import networkx as nx
import matplotlib.pyplot as plt

# %%
device = t.device("cuda" if t.cuda.is_available() else "cpu")
model = tl.HookedTransformer.from_pretrained("attn-only-2l")

# NOTE. The following lines are present in the code of the official repo,
# but I don't know what it really does.

model.set_use_attn_result(True)     
model.set_use_split_qkv_input(True)
# Out:
# Loaded pretrained model attn-only-2l into HookedTransformer

# %%
for name, parameters in model.named_parameters():
    print(f"{name}: {parameters.shape}")
# Out:
# embed.W_E: torch.Size([48262, 512])
# pos_embed.W_pos: torch.Size([1024, 512])
# blocks.0.attn.W_Q: torch.Size([8, 512, 64])
# blocks.0.attn.W_O: torch.Size([8, 64, 512])
# blocks.0.attn.b_Q: torch.Size([8, 64])
# blocks.0.attn.b_O: torch.Size([512])
# blocks.0.attn.W_K: torch.Size([8, 512, 64])
# blocks.0.attn.W_V: torch.Size([8, 512, 64])
# blocks.0.attn.b_K: torch.Size([8, 64])
# blocks.0.attn.b_V: torch.Size([8, 64])
# blocks.1.attn.W_Q: torch.Size([8, 512, 64])
# blocks.1.attn.W_O: torch.Size([8, 64, 512])
# blocks.1.attn.b_Q: torch.Size([8, 64])
# blocks.1.attn.b_O: torch.Size([512])
# blocks.1.attn.W_K: torch.Size([8, 512, 64])
# blocks.1.attn.W_V: torch.Size([8, 512, 64])
# blocks.1.attn.b_K: torch.Size([8, 64])
# blocks.1.attn.b_V: torch.Size([8, 64])
# unembed.W_U: torch.Size([512, 48262])
# unembed.b_U: torch.Size([48262])

# %%
# NOTE. Edges from the ACDC package, maybe we should create a method to compare our graph to theirs.

correspondence = TLACDCCorrespondence.setup_from_model(model)
correspondence.edges
# Out:
# OrderedDefaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>()>,
#                    {'blocks.1.hook_resid_post': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.attn.hook_result': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)})})}),
#                     'blocks.1.attn.hook_q': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_k': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_v': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.hook_v_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.attn.hook_result': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
# ...
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_q_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.attn.hook_k': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_k_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.attn.hook_v': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_v_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})})})

# %%
# NOTE. I got this code from ARENA.

def generate_repeated_tokens(
    model: tl.HookedTransformer, seq_len: int, batch: int = 1
) -> t.Tensor:
    prefix = (t.ones(batch, 1) * model.tokenizer.bos_token_id).long()
    rep_tokens_half = t.randint(0, model.cfg.d_vocab, (batch, seq_len), dtype=t.int64)
    rep_tokens = t.cat([prefix, rep_tokens_half, rep_tokens_half], dim=-1).to(device)
    return rep_tokens

dataset = generate_repeated_tokens(model=model, seq_len=5, batch=100)[:, :-1]
dataset.shape
# Out:
# torch.Size([100, 10])

# %%
logits, cache = model.run_with_cache(dataset)
for name, values in cache.items():
    print(f"{name}: {values.shape}")
# Out:
# hook_embed: torch.Size([100, 10, 512])
# hook_pos_embed: torch.Size([100, 10, 512])
# blocks.0.hook_resid_pre: torch.Size([100, 10, 512])
# blocks.0.hook_q_input: torch.Size([100, 10, 8, 512])
# blocks.0.hook_k_input: torch.Size([100, 10, 8, 512])
# blocks.0.hook_v_input: torch.Size([100, 10, 8, 512])
# blocks.0.ln1.hook_scale: torch.Size([100, 10, 8, 1])
# blocks.0.ln1.hook_normalized: torch.Size([100, 10, 8, 512])
# blocks.0.attn.hook_q: torch.Size([100, 10, 8, 64])
# blocks.0.attn.hook_k: torch.Size([100, 10, 8, 64])
# blocks.0.attn.hook_v: torch.Size([100, 10, 8, 64])
# blocks.0.attn.hook_attn_scores: torch.Size([100, 8, 10, 10])
# blocks.0.attn.hook_pattern: torch.Size([100, 8, 10, 10])
# blocks.0.attn.hook_z: torch.Size([100, 10, 8, 64])
# blocks.0.attn.hook_result: torch.Size([100, 10, 8, 512])
# blocks.0.hook_attn_out: torch.Size([100, 10, 512])
# blocks.0.hook_resid_post: torch.Size([100, 10, 512])
# blocks.1.hook_resid_pre: torch.Size([100, 10, 512])
# blocks.1.hook_q_input: torch.Size([100, 10, 8, 512])
# blocks.1.hook_k_input: torch.Size([100, 10, 8, 512])
# blocks.1.hook_v_input: torch.Size([100, 10, 8, 512])
# blocks.1.ln1.hook_scale: torch.Size([100, 10, 8, 1])
# blocks.1.ln1.hook_normalized: torch.Size([100, 10, 8, 512])
# blocks.1.attn.hook_q: torch.Size([100, 10, 8, 64])
# blocks.1.attn.hook_k: torch.Size([100, 10, 8, 64])
# blocks.1.attn.hook_v: torch.Size([100, 10, 8, 64])
# blocks.1.attn.hook_attn_scores: torch.Size([100, 8, 10, 10])
# blocks.1.attn.hook_pattern: torch.Size([100, 8, 10, 10])
# blocks.1.attn.hook_z: torch.Size([100, 10, 8, 64])
# blocks.1.attn.hook_result: torch.Size([100, 10, 8, 512])
# blocks.1.hook_attn_out: torch.Size([100, 10, 512])
# blocks.1.hook_resid_post: torch.Size([100, 10, 512])
# ln_final.hook_scale: torch.Size([100, 10, 1])
# ln_final.hook_normalized: torch.Size([100, 10, 512])

# %%
@dc.dataclass(frozen=True)
class TransformerNode:
    hook_name: str
    head_idx: Optional[int] = None

    @property
    def index(self):
        colon = slice(None)
        head_idx = self.head_idx

        if head_idx: return tuple([colon, colon, head_idx, colon])
        else: return tuple([colon, colon, colon])
    
    def __repr__(self):
        head_idx = self.head_idx
        return f"N({self.hook_name}{f'({head_idx})' if head_idx is not None else ''})"

class TransformerEdgeType(Enum):
    ADDITION = 0
    DIRECT_COMPUTATION = 1
    PLACEHOLDER = 2

    def __repr__(self):
        return self.name

def setup_nx_graph_from_model(model: tl.HookedTransformer):
    graph = nx.DiGraph()
    
    n_layers = model.cfg.n_layers
    residual_stream_nodes: list[TransformerNode] = []

    logits_node = TransformerNode(f"blocks.{n_layers-1}.hook_resid_post")

    graph.add_node(logits_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset="logits")
    residual_stream_nodes.append(logits_node)

    for layer_idx in range(model.cfg.n_layers - 1, -1, -1):
        new_residual_stream_nodes: list[TransformerNode] = []

        for head_idx in range(model.cfg.n_heads - 1, -1, -1):
            cur_head_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_result", head_idx)
            graph.add_node(cur_head_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset=f"layer {layer_idx} result")
    
            for residual_stream_node in residual_stream_nodes:
                graph.add_edge(
                    cur_head_node, residual_stream_node,
                    edge_type=TransformerEdgeType.ADDITION,
                )

            for letter in "qkv":
                letter_hook_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_{letter}", head_idx)
                graph.add_node(letter_hook_node, incoming_edge_type=TransformerEdgeType.DIRECT_COMPUTATION, subset=f"layer {layer_idx} letter")

                letter_input_hook_node = TransformerNode(f"blocks.{layer_idx}.hook_{letter}_input", head_idx)
                graph.add_node(letter_input_hook_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset=f"layer {layer_idx} input")

                graph.add_edge(
                    letter_hook_node, cur_head_node,
                    edge_type=TransformerEdgeType.PLACEHOLDER,
                )

                graph.add_edge(
                    letter_input_hook_node, letter_hook_node,
                    edge_type=TransformerEdgeType.DIRECT_COMPUTATION,
                )

                new_residual_stream_nodes.append(letter_input_hook_node)

        residual_stream_nodes.extend(new_residual_stream_nodes)

    token_embed_node = TransformerNode(hook_name="hook_embed")
    pos_embed_node = TransformerNode("hook_pos_embed")

    # NOTE. For now, we will always include the positional embedding node. 

    embed_nodes = [token_embed_node, pos_embed_node]

    for embed_node in embed_nodes:
        graph.add_node(embed_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset="embed")

        for residual_stream_node in residual_stream_nodes:
            graph.add_edge(
                embed_node, residual_stream_node,
                edge_type=TransformerEdgeType.ADDITION
            )

    for u, v, data in graph.edges.data():
        data["present"] = True
        v = graph.nodes[v]
        assert data["edge_type"] == v["incoming_edge_type"]

    return graph

# %%
graph = setup_nx_graph_from_model(model)

plt.figure(figsize=(12, 6))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(graph, pos, node_size=50)
nx.draw_networkx_edges(graph, pos, node_size=50, alpha=0.5)
plt.show()

# %%
# Setup corrupted cache

model.reset_hooks()

model.add_hook(
    name = lambda hook_name: any([substring in hook_name for substring in ["hook_result", "hook_pos_embed", "hook_embed"]]),
    hook = lambda z, hook: t.zeros_like(z))
_, corrupted_cache = model.run_with_cache(dataset)

model.reset_hooks()

corrupted_cache
# Out:
# ActivationCache with keys ['hook_embed', 'hook_pos_embed', 'blocks.0.hook_resid_pre', 'blocks.0.hook_q_input', 'blocks.0.hook_k_input', 'blocks.0.hook_v_input', 'blocks.0.ln1.hook_scale', 'blocks.0.ln1.hook_normalized', 'blocks.0.attn.hook_q', 'blocks.0.attn.hook_k', 'blocks.0.attn.hook_v', 'blocks.0.attn.hook_attn_scores', 'blocks.0.attn.hook_pattern', 'blocks.0.attn.hook_z', 'blocks.0.attn.hook_result', 'blocks.0.hook_attn_out', 'blocks.0.hook_resid_post', 'blocks.1.hook_resid_pre', 'blocks.1.hook_q_input', 'blocks.1.hook_k_input', 'blocks.1.hook_v_input', 'blocks.1.ln1.hook_scale', 'blocks.1.ln1.hook_normalized', 'blocks.1.attn.hook_q', 'blocks.1.attn.hook_k', 'blocks.1.attn.hook_v', 'blocks.1.attn.hook_attn_scores', 'blocks.1.attn.hook_pattern', 'blocks.1.attn.hook_z', 'blocks.1.attn.hook_result', 'blocks.1.hook_attn_out', 'blocks.1.hook_resid_post', 'ln_final.hook_scale', 'ln_final.hook_normalized']

# %%
online_cache = dict()

# %%
def receiver_hook(hook_tensor, hook):
    hook_nodes = [node for node in graph.nodes if node.hook_name == hook.name]
    incoming_edge_types = [graph.nodes[node]['incoming_edge_type'] for node in hook_nodes]
    
    if TransformerEdgeType.DIRECT_COMPUTATION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.DIRECT_COMPUTATION for _ in incoming_edge_types], f"All incoming edges should be the same type not {incoming_edge_types}"
    
        old_z = hook_tensor.clone()
        hook_tensor[:] = corrupted_cache[hook.name]
    
        for receiver in hook_nodes:
            senders = [sender for sender, _, data in graph.in_edges(receiver, data=True) if edge[2]["present"]]
            print(senders)
            assert len(senders) <= 1, "This is a direct computation, so there should only be one sender node"
            if len(senders) == 0: continue

            hook_tensor[receiver.index] = old_z[receiver.index]
    
    if TransformerEdgeType.ADDITION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.ADDITION for _ in incoming_edge_types], f"All incoming edges should be the same type, not {incoming_edge_types}"
        hook_tensor[:] = corrupted_cache[hook.name]
        
        for receiver in hook_nodes:
            for sender, _, data in graph.in_edges(receiver, data=True):
                if not data["present"]: continue

                assert data["edge_type"] == TransformerEdgeType.ADDITION
            
                hook_tensor[receiver.index] += online_cache[sender.hook_name][sender.index]
                hook_tensor[receiver.index] -= corrupted_cache[sender.hook_name][sender.index]

    return hook_tensor

# %%
def sender_hook(hook_tensor, hook):
    print(hook)
    online_cache[hook.name] = hook_tensor
    return hook_tensor

# %%
model.reset_hooks()
receiver_hook_names = set([node.hook_name for node, data in graph.nodes(data=True) if data["incoming_edge_type"] != TransformerEdgeType.PLACEHOLDER])

for hook_name in receiver_hook_names:
    model.add_hook(
        name=hook_name,
        hook=receiver_hook)

    model.add_hook(
        name=hook_name,
        hook=sender_hook)

model.run_with_cache(dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 13
#       5     model.add_hook(
#       6         name=hook_name,
#       7         hook=receiver_hook)
#       9     model.add_hook(
#      10         name=hook_name,
#      11         hook=sender_hook)
# ---> 13 model.run_with_cache(dataset)
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:648, in HookedTransformer.run_with_cache(self, return_cache_object, remove_batch_dim, *model_args, **kwargs)
#     631 def run_with_cache(
#     632     self, *model_args, return_cache_object=True, remove_batch_dim=False, **kwargs
#     633 ) -> Tuple[
#    (...)
#     640     Union[ActivationCache, Dict[str, torch.Tensor]],
#     641 ]:
#     642     """Wrapper around `run_with_cache` in HookedRootModule.
#     643
#     644     If return_cache_object is True, this will return an ActivationCache object, with a bunch of
#     645     useful HookedTransformer specific methods, otherwise it will return a dictionary of
#     646     activations as in HookedRootModule.
#     647     """
# --> 648     out, cache_dict = super().run_with_cache(
#     649         *model_args, remove_batch_dim=remove_batch_dim, **kwargs
#     650     )
#     651     if return_cache_object:
#     652         cache = ActivationCache(
#     653             cache_dict, self, has_batch_dim=not remove_batch_dim
#     654         )
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformer_lens/hook_points.py:467, in HookedRootModule.run_with_cache(self, names_filter, device, remove_batch_dim, incl_bwd, reset_hooks_end, clear_contexts, *model_args, **model_kwargs)
#     457 cache_dict, fwd, bwd = self.get_caching_hooks(
#     458     names_filter, incl_bwd, device, remove_batch_dim=remove_batch_dim
#     459 )
#     461 with self.hooks(
#     462     fwd_hooks=fwd,
#     463     bwd_hooks=bwd,
#     464     reset_hooks_end=reset_hooks_end,
#     465     clear_contexts=clear_contexts,
#     466 ):
# --> 467     model_out = self(*model_args, **model_kwargs)
#     468     if incl_bwd:
#     469         model_out.backward()
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformer_lens/HookedTransformer.py:569, in HookedTransformer.forward(self, input, return_type, loss_per_token, prepend_bos, padding_side, start_at_layer, tokens, shortformer_pos_embed, attention_mask, stop_at_layer, past_kv_cache)
#     564     if shortformer_pos_embed is not None:
#     565         shortformer_pos_embed = shortformer_pos_embed.to(
#     566             devices.get_device_for_block_index(i, self.cfg)
#     567         )
# --> 569     residual = block(
#     570         residual,
#     571         # Cache contains a list of HookedTransformerKeyValueCache objects, one for each
#     572         # block
#     573         past_kv_cache_entry=past_kv_cache[i]
#     574         if past_kv_cache is not None
#     575         else None,
#     576         shortformer_pos_embed=shortformer_pos_embed,
#     577         attention_mask=attention_mask,
#     578     )  # [batch, pos, d_model]
#     580 if stop_at_layer is not None:
#     581     # When we stop at an early layer, we end here rather than doing further computation
#     582     return residual
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformer_lens/components.py:1432, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry, attention_mask)
#    1429     attn_in = self.hook_attn_in(attn_in.clone())
#    1431 if self.cfg.use_split_qkv_input:
# -> 1432     query_input = self.hook_q_input(attn_in.clone())
#    1433     key_input = self.hook_k_input(attn_in.clone())
#    1434     value_input = self.hook_v_input(attn_in.clone())
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/torch/nn/modules/module.py:1595, in Module._call_impl(self, *args, **kwargs)
#    1593     hook_result = hook(self, args, kwargs, result)
#    1594 else:
# -> 1595     hook_result = hook(self, args, result)
#    1597 if hook_result is not None:
#    1598     result = hook_result
#
# File ~/.asdf/installs/python/3.11.9/lib/python3.11/site-packages/transformer_lens/hook_points.py:65, in HookPoint.add_hook.<locals>.full_hook(module, module_input, module_output)
#      64 def full_hook(module, module_input, module_output):
# ---> 65     return hook(module_output, hook=self)
#
# Cell In[39], line 29, in receiver_hook(hook_tensor, hook)
#      25             if not data["present"]: continue
#      27             assert data["edge_type"] == TransformerEdgeType.ADDITION
# ---> 29             hook_tensor[receiver.index] += online_cache[sender.hook_name][sender.index]
#      30             hook_tensor[receiver.index] -= corrupted_cache[sender.hook_name][sender.index]
#      32 return hook_tensor
#
# KeyError: 'hook_embed'
