# %%
import transformer_lens as tl
import torch as t
import torch.nn.functional as F
from acdc.TLACDCExperiment import TLACDCCorrespondence
import dataclasses as dc
from typing import Optional
from enum import Enum
from pprint import pprint
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import random

flatten = itertools.chain.from_iterable

# %%
device = t.device("cuda" if t.cuda.is_available() else "cpu")

cfg = tl.HookedTransformerConfig(
    d_model=768,
    d_head=64,
    n_heads=12,
    n_layers=2,
    n_ctx=2048,
    d_vocab=50278,
    attention_dir="causal",
    attn_only=True, # defaults to False
    tokenizer_name="EleutherAI/gpt-neox-20b", 
    seed=398,
    use_attn_result=True,
    use_split_qkv_input=True,
    normalization_type=None, # defaults to "LN", i.e. layernorm with weights & biases
    positional_embedding_type="shortformer"
)

from huggingface_hub import hf_hub_download

REPO_ID = "callummcdougall/attn_only_2L_half"
FILENAME = "attn_only_2L_half.pth"

weights_path = hf_hub_download(repo_id=REPO_ID, filename=FILENAME)
print(weights_path)

model = tl.HookedTransformer(cfg).to(device)
pretrained_weights = t.load(weights_path, map_location=device)
model.load_state_dict(pretrained_weights)

# model = tl.HookedTransformer.from_pretrained("attn-only-2l")
# model = model.to(device)

# NOTE. The following lines are present in the code of the official repo,
# but I don't know what it really does.

# model.set_use_attn_result(True)     
# model.set_use_split_qkv_input(True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Moving model to device:  cuda
# <All keys matched successfully>

# %%
for name, parameters in model.named_parameters():
    print(f"{name}: {parameters.shape}")
# Out:
# embed.W_E: torch.Size([50278, 768])
# pos_embed.W_pos: torch.Size([2048, 768])
# blocks.0.attn.W_Q: torch.Size([12, 768, 64])
# blocks.0.attn.W_O: torch.Size([12, 64, 768])
# blocks.0.attn.b_Q: torch.Size([12, 64])
# blocks.0.attn.b_O: torch.Size([768])
# blocks.0.attn.W_K: torch.Size([12, 768, 64])
# blocks.0.attn.W_V: torch.Size([12, 768, 64])
# blocks.0.attn.b_K: torch.Size([12, 64])
# blocks.0.attn.b_V: torch.Size([12, 64])
# blocks.1.attn.W_Q: torch.Size([12, 768, 64])
# blocks.1.attn.W_O: torch.Size([12, 64, 768])
# blocks.1.attn.b_Q: torch.Size([12, 64])
# blocks.1.attn.b_O: torch.Size([768])
# blocks.1.attn.W_K: torch.Size([12, 768, 64])
# blocks.1.attn.W_V: torch.Size([12, 768, 64])
# blocks.1.attn.b_K: torch.Size([12, 64])
# blocks.1.attn.b_V: torch.Size([12, 64])
# unembed.W_U: torch.Size([768, 50278])
# unembed.b_U: torch.Size([50278])

# %%
# NOTE. Edges from the ACDC package, maybe we should create a method to compare our graph to theirs.

correspondence = TLACDCCorrespondence.setup_from_model(model)
correspondence.edges
# Out:
# OrderedDefaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>()>,
#                    {'blocks.1.hook_resid_post': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.attn.hook_result': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.PLACEHOLDER, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.attn.hook_q': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_k': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)}),
#                                               'blocks.1.attn.hook_v': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.PLACEHOLDER, True)})})}),
#                     'blocks.1.attn.hook_q': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_q_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_k': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_k_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.attn.hook_v': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 10]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 9]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.1.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.1.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.1.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 6]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 5]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 4]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 3]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 2]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 1]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 0]: Edge(EdgeType.ADDITION, True)}),
#                                               'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.attn.hook_result': defaultdict(None,
#                                                           {[:, :, 11]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 10]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 9]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 8]: Edge(EdgeType.ADDITION, True),
#                                                            [:, :, 7]: Edge(EdgeType.ADDITION, True),
# ...
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 8]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 7]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 6]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 5]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 4]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 3]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 2]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 1]: Edge(EdgeType.DIRECT_COMPUTATION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_v_input': defaultdict(None,
#                                                           {[:, :, 0]: Edge(EdgeType.DIRECT_COMPUTATION, True)})})}),
#                     'blocks.0.hook_q_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_k_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})}),
#                     'blocks.0.hook_v_input': defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>()>,
#                                 {[:, :, 11]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 10]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 9]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 8]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 7]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 6]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 5]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 4]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 3]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 2]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 1]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})}),
#                                  [:, :, 0]: defaultdict(<function acdc.acdc_utils.make_nd_dict.<locals>.<lambda>.<locals>.<lambda>.<locals>.<lambda>()>,
#                                              {'blocks.0.hook_resid_pre': defaultdict(None,
#                                                           {[:]: Edge(EdgeType.ADDITION, True)})})})})

# %%
# NOTE. I got this code from ARENA.

def generate_repeated_tokens(
    model: tl.HookedTransformer,
    seq_len: int,
    num_seq: int = 1
) -> t.Tensor:
    prefix = (t.ones(num_seq, 1) * model.tokenizer.bos_token_id).long()
    rep_tokens_half = t.randint(0, model.cfg.d_vocab, (num_seq, seq_len), dtype=t.int64)
    rep_tokens = t.cat([prefix, rep_tokens_half, rep_tokens_half], dim=-1).to(device)
    return rep_tokens

seq_len = 100
num_seq = 25

dataset = generate_repeated_tokens(model=model, seq_len=seq_len, num_seq=num_seq)[:, :-1]
dataset.shape
# Out:
# torch.Size([25, 200])

# %%
logits, cache = model.run_with_cache(dataset)
for name, values in cache.items():
    print(f"{name}: {values.shape}")
# Out:
# hook_embed: torch.Size([25, 200, 768])
# hook_pos_embed: torch.Size([25, 200, 768])
# blocks.0.hook_resid_pre: torch.Size([25, 200, 768])
# blocks.0.hook_q_input: torch.Size([25, 200, 12, 768])
# blocks.0.hook_k_input: torch.Size([25, 200, 12, 768])
# blocks.0.hook_v_input: torch.Size([25, 200, 12, 768])
# blocks.0.attn.hook_q: torch.Size([25, 200, 12, 64])
# blocks.0.attn.hook_k: torch.Size([25, 200, 12, 64])
# blocks.0.attn.hook_v: torch.Size([25, 200, 12, 64])
# blocks.0.attn.hook_attn_scores: torch.Size([25, 12, 200, 200])
# blocks.0.attn.hook_pattern: torch.Size([25, 12, 200, 200])
# blocks.0.attn.hook_z: torch.Size([25, 200, 12, 64])
# blocks.0.attn.hook_result: torch.Size([25, 200, 12, 768])
# blocks.0.hook_attn_out: torch.Size([25, 200, 768])
# blocks.0.hook_resid_post: torch.Size([25, 200, 768])
# blocks.1.hook_resid_pre: torch.Size([25, 200, 768])
# blocks.1.hook_q_input: torch.Size([25, 200, 12, 768])
# blocks.1.hook_k_input: torch.Size([25, 200, 12, 768])
# blocks.1.hook_v_input: torch.Size([25, 200, 12, 768])
# blocks.1.attn.hook_q: torch.Size([25, 200, 12, 64])
# blocks.1.attn.hook_k: torch.Size([25, 200, 12, 64])
# blocks.1.attn.hook_v: torch.Size([25, 200, 12, 64])
# blocks.1.attn.hook_attn_scores: torch.Size([25, 12, 200, 200])
# blocks.1.attn.hook_pattern: torch.Size([25, 12, 200, 200])
# blocks.1.attn.hook_z: torch.Size([25, 200, 12, 64])
# blocks.1.attn.hook_result: torch.Size([25, 200, 12, 768])
# blocks.1.hook_attn_out: torch.Size([25, 200, 768])
# blocks.1.hook_resid_post: torch.Size([25, 200, 768])

# %%
@dc.dataclass(frozen=True)
class TransformerNode:
    hook_name: str
    head_idx: Optional[int] = None

    @property
    def index(self):
        colon = slice(None)
        head_idx = self.head_idx

        if head_idx is not None: return tuple([colon, colon, head_idx, colon])
        else: return tuple([colon, colon, colon])
    
    def __repr__(self):
        head_idx = self.head_idx
        return f"N({self.hook_name}{f'({head_idx})' if head_idx is not None else ''})"

class TransformerEdgeType(Enum):
    ADDITION = 0
    DIRECT_COMPUTATION = 1
    PLACEHOLDER = 2

    def __repr__(self):
        return self.name

def setup_nx_graph_from_model(model: tl.HookedTransformer):
    graph = nx.DiGraph()
    
    n_layers = model.cfg.n_layers
    residual_stream_nodes: list[TransformerNode] = []

    logits_node = TransformerNode(f"blocks.{n_layers-1}.hook_resid_post")

    graph.add_node(logits_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset="logits")
    residual_stream_nodes.append(logits_node)

    for layer_idx in range(model.cfg.n_layers - 1, -1, -1):
        new_residual_stream_nodes: list[TransformerNode] = []

        for head_idx in range(model.cfg.n_heads - 1, -1, -1):
            cur_head_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_result", head_idx)
            graph.add_node(cur_head_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset=f"layer {layer_idx} result")
    
            for residual_stream_node in residual_stream_nodes:
                graph.add_edge(
                    cur_head_node, residual_stream_node,
                    edge_type=TransformerEdgeType.ADDITION,
                )

            for letter in "qkv":
                letter_hook_node = TransformerNode(f"blocks.{layer_idx}.attn.hook_{letter}", head_idx)
                graph.add_node(letter_hook_node, incoming_edge_type=TransformerEdgeType.DIRECT_COMPUTATION, subset=f"layer {layer_idx} letter")

                letter_input_hook_node = TransformerNode(f"blocks.{layer_idx}.hook_{letter}_input", head_idx)
                graph.add_node(letter_input_hook_node, incoming_edge_type=TransformerEdgeType.ADDITION, subset=f"layer {layer_idx} input")

                graph.add_edge(
                    letter_hook_node, cur_head_node,
                    edge_type=TransformerEdgeType.PLACEHOLDER,
                )

                graph.add_edge(
                    letter_input_hook_node, letter_hook_node,
                    edge_type=TransformerEdgeType.DIRECT_COMPUTATION,
                )

                new_residual_stream_nodes.append(letter_input_hook_node)

        residual_stream_nodes.extend(new_residual_stream_nodes)

    token_embed_node = TransformerNode(hook_name="hook_embed")
    # pos_embed_node = TransformerNode("hook_pos_embed")

    # NOTE. For now, we will always include the positional embedding node. 

    embed_nodes = [token_embed_node]#, pos_embed_node]

    for embed_node in embed_nodes:
        graph.add_node(embed_node, incoming_edge_type=TransformerEdgeType.PLACEHOLDER, subset="embed")

        for residual_stream_node in residual_stream_nodes:
            graph.add_edge(
                embed_node, residual_stream_node,
                edge_type=TransformerEdgeType.ADDITION
            )

    for u, v, data in graph.edges.data():
        data["present"] = True
        v = graph.nodes[v]
        assert data["edge_type"] == v["incoming_edge_type"]

    return graph

# %%
graph = setup_nx_graph_from_model(model)

plt.figure(figsize=(12, 6))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(graph, pos, node_size=50)
nx.draw_networkx_edges(graph, pos, node_size=50, alpha=0.5)
plt.show()

# %%
# Setup corrupted and online cache

model.reset_hooks()

model.add_hook(
    name = lambda hook_name: any([substring in hook_name for substring in ["hook_result", "hook_pos_embed", "hook_embed"]]),
    hook = lambda z, hook: t.zeros_like(z))

_, corrupted_cache = model.run_with_cache(dataset)
online_cache = dict()

model.reset_hooks()

# %%
def receiver_hook(hook_tensor, hook):
    hook_nodes = [node for node in graph.nodes if node.hook_name == hook.name]
    incoming_edge_types = [graph.nodes[node]['incoming_edge_type'] for node in hook_nodes]
    
    if TransformerEdgeType.DIRECT_COMPUTATION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.DIRECT_COMPUTATION for _ in incoming_edge_types], f"All incoming edges should be the same type not {incoming_edge_types}"
    
        old_z = hook_tensor.clone()
        hook_tensor[:] = corrupted_cache[hook.name]
    
        for receiver in hook_nodes:
            senders = [sender for sender, _, data in graph.in_edges(receiver, data=True) if data["present"]]

            assert len(senders) <= 1, "This is a direct computation, so there should only be one sender node"
            if len(senders) == 0: continue

            hook_tensor[receiver.index] = old_z[receiver.index]

    
    if TransformerEdgeType.ADDITION in incoming_edge_types:
        assert incoming_edge_types == [TransformerEdgeType.ADDITION for _ in incoming_edge_types], f"All incoming edges should be the same type, not {incoming_edge_types}"
        hook_tensor[:] = corrupted_cache[hook.name]
        
        for receiver in hook_nodes:
            for sender, _, data in graph.in_edges(receiver, data=True):
                if not data["present"]:
                    continue

                assert data["edge_type"] == TransformerEdgeType.ADDITION
            
                hook_tensor[receiver.index] += online_cache[sender.hook_name][sender.index]
                hook_tensor[receiver.index] -= corrupted_cache[sender.hook_name][sender.index]
    
    return hook_tensor

def sender_hook(hook_tensor, hook):
    online_cache[hook.name] = hook_tensor
    return hook_tensor

# %%
model.reset_hooks()

receiver_hook_names = set([
    node.hook_name
    for node, data in graph.nodes(data=True)
    if data["incoming_edge_type"] != TransformerEdgeType.PLACEHOLDER])

for hook_name in receiver_hook_names:
    model.add_hook(
        name=hook_name,
        hook=receiver_hook)

sender_hook_names = set(flatten([
    [sender.hook_name, receiver.hook_name]
    for sender, receiver, data
    in graph.edges(data=True)
    if data["edge_type"] != TransformerEdgeType.PLACEHOLDER]))

for hook_name in sender_hook_names:
    model.add_hook(
        name=hook_name,
        hook=sender_hook)

# %%
graph[TransformerNode("blocks.1.attn.hook_result", 0)][TransformerNode("blocks.1.hook_resid_post")]["present"] = True

# %%
# NOTE. Ratio of sequences that have the associated argmax logit as the correct one.

logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.3999999761581421

# %%
# NOTE. Just a test, removing random edges.
for sender, receiver, data in graph.edges(data=True):
    data["present"] = True

    if random.random() < 0.01:
        data["present"] = False

logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# N(hook_embed) to N(blocks.1.hook_k_input(3)) not present
# N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(8)) not present
# N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(7)) not present
# N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_resid_post) not present
# 0.3999999761581421

# %%
def kl_divergence(current_logits, corrupted_logits):
    current_dist = t.distributions.Categorical(logits=current_logits)
    corrupted_dist = t.distributions.Categorical(logits=corrupted_logits)

    kl_div = t.distributions.kl_divergence(current_dist, corrupted_dist).mean()
    return kl_div.item()

# %%
def pruning(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    # model.reset_hooks()
    topological_sort_nodes = list(nx.topological_sort(graph))
    
    for receiver in reversed(topological_sort_nodes):
        if graph.nodes[receiver]['incoming_edge_type'] == TransformerEdgeType.PLACEHOLDER:
            continue

        out_edges = graph.out_edges(receiver, data=True)

        if len(out_edges) > 0 and all(not data["present"] for _, _, data in out_edges):
            print(f"All out edges from {receiver} are not present, pruning all in edges.")
            for sender, _, data in graph.in_edges(receiver, data=True):
                print(f"Pruned edge from {sender} to {receiver}.")
                data["present"] = False
    
        # Temporarily remove each incoming edge
        for sender, _, data in graph.in_edges(receiver, data=True):
            if data["present"]:
                current_output = model(dataset)[:, -1, :]
                data["present"] = False
                corrupted_output = model(dataset)[:, -1, :]

                # _, corrupted_cache = model.run_with_cache(dataset)
                kl_div = kl_divergence(current_output, corrupted_output)
                
                if kl_div < threshold:
                    print(f"Pruned edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = False
                else:
                    print(f"Kept edge from {sender} to {receiver} with KL divergence {kl_div}.")
                    data["present"] = True

        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

    for receiver in topological_sort_nodes:
        in_edges = graph.in_edges(receiver, data=True)

        if len(in_edges) > 0 and all(not data["present"] for _, _, data in in_edges):
            print(f"All in edges to {receiver} are not present, pruning all out edges.")
            for _, receiver_receiver, data in graph.out_edges(receiver, data=True):
                print(f"Pruned edge from {receiver} to {receiver_receiver}.")
                data["present"] = False

# %%
def ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01):
    for _, _, data in graph.edges(data=True):
        data["present"] = True
    
    pruning(graph, model, dataset, corrupted_cache, online_cache, threshold) 

ACDC(graph, model, dataset, corrupted_cache, online_cache, threshold=0.01)
# Out:
# Kept edge from N(blocks.1.attn.hook_result(11)) to N(blocks.1.hook_resid_post) with KL divergence 0.10989440977573395.
# Kept edge from N(blocks.1.attn.hook_result(10)) to N(blocks.1.hook_resid_post) with KL divergence 0.9925301671028137.
# Kept edge from N(blocks.1.attn.hook_result(9)) to N(blocks.1.hook_resid_post) with KL divergence 0.07181932777166367.
# Kept edge from N(blocks.1.attn.hook_result(8)) to N(blocks.1.hook_resid_post) with KL divergence 0.07695703953504562.
# Kept edge from N(blocks.1.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.0918860211968422.
# Kept edge from N(blocks.1.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 0.13909941911697388.
# Kept edge from N(blocks.1.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.15659907460212708.
# Kept edge from N(blocks.1.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.9097651243209839.
# Kept edge from N(blocks.1.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.06915421038866043.
# Kept edge from N(blocks.1.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.11744939535856247.
# Kept edge from N(blocks.1.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.05898263305425644.
# Kept edge from N(blocks.1.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.08749832212924957.
# Kept edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_resid_post) with KL divergence 0.11458087712526321.
# Kept edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_resid_post) with KL divergence 0.029242798686027527.
# Kept edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_resid_post) with KL divergence 0.04839172214269638.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_resid_post) with KL divergence 0.00641008373349905.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_resid_post) with KL divergence 0.06129826232790947.
# Kept edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_resid_post) with KL divergence 0.011960637755692005.
# Kept edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_resid_post) with KL divergence 0.011575891636312008.
# Kept edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_resid_post) with KL divergence 0.016622725874185562.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_resid_post) with KL divergence 0.06570883840322495.
# Kept edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post) with KL divergence 0.010117372497916222.
# Kept edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_resid_post) with KL divergence 0.03061121702194214.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_resid_post) with KL divergence 0.009724239818751812.
# Kept edge from N(hook_embed) to N(blocks.1.hook_resid_post) with KL divergence 0.3667711317539215.
# Kept edge from N(blocks.1.hook_v_input(0)) to N(blocks.1.attn.hook_v(0)) with KL divergence 0.08755221962928772.
# Kept edge from N(blocks.1.hook_k_input(0)) to N(blocks.1.attn.hook_k(0)) with KL divergence 0.28885120153427124.
# Kept edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)) with KL divergence 0.28885120153427124.
# Kept edge from N(blocks.1.hook_v_input(1)) to N(blocks.1.attn.hook_v(1)) with KL divergence 0.05929314345121384.
# Kept edge from N(blocks.1.hook_k_input(1)) to N(blocks.1.attn.hook_k(1)) with KL divergence 0.06520131975412369.
# Kept edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)) with KL divergence 0.06520131975412369.
# Kept edge from N(blocks.1.hook_v_input(2)) to N(blocks.1.attn.hook_v(2)) with KL divergence 0.11657395958900452.
# Kept edge from N(blocks.1.hook_k_input(2)) to N(blocks.1.attn.hook_k(2)) with KL divergence 0.36835113167762756.
# Kept edge from N(blocks.1.hook_q_input(2)) to N(blocks.1.attn.hook_q(2)) with KL divergence 0.36835113167762756.
# Kept edge from N(blocks.1.hook_v_input(3)) to N(blocks.1.attn.hook_v(3)) with KL divergence 0.0676528736948967.
# Kept edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)) with KL divergence 0.0671573281288147.
# Kept edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)) with KL divergence 0.0671573281288147.
# Kept edge from N(blocks.1.hook_v_input(4)) to N(blocks.1.attn.hook_v(4)) with KL divergence 0.9215636253356934.
# Kept edge from N(blocks.1.hook_k_input(4)) to N(blocks.1.attn.hook_k(4)) with KL divergence 0.9305967688560486.
# Kept edge from N(blocks.1.hook_q_input(4)) to N(blocks.1.attn.hook_q(4)) with KL divergence 0.9305967688560486.
# Kept edge from N(blocks.1.hook_v_input(5)) to N(blocks.1.attn.hook_v(5)) with KL divergence 0.15735550224781036.
# Kept edge from N(blocks.1.hook_k_input(5)) to N(blocks.1.attn.hook_k(5)) with KL divergence 0.27151256799697876.
# Kept edge from N(blocks.1.hook_q_input(5)) to N(blocks.1.attn.hook_q(5)) with KL divergence 0.27151256799697876.
# Kept edge from N(blocks.1.hook_v_input(6)) to N(blocks.1.attn.hook_v(6)) with KL divergence 0.13943378627300262.
# Kept edge from N(blocks.1.hook_k_input(6)) to N(blocks.1.attn.hook_k(6)) with KL divergence 0.1979522705078125.
# Kept edge from N(blocks.1.hook_q_input(6)) to N(blocks.1.attn.hook_q(6)) with KL divergence 0.1979522705078125.
# Kept edge from N(blocks.1.hook_v_input(7)) to N(blocks.1.attn.hook_v(7)) with KL divergence 0.0915236547589302.
# Kept edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)) with KL divergence 0.06598526239395142.
# Kept edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)) with KL divergence 0.06598526239395142.
# Kept edge from N(blocks.1.hook_v_input(8)) to N(blocks.1.attn.hook_v(8)) with KL divergence 0.0767252966761589.
# Kept edge from N(blocks.1.hook_k_input(8)) to N(blocks.1.attn.hook_k(8)) with KL divergence 0.054866597056388855.
# Kept edge from N(blocks.1.hook_q_input(8)) to N(blocks.1.attn.hook_q(8)) with KL divergence 0.054866597056388855.
# Kept edge from N(blocks.1.hook_v_input(9)) to N(blocks.1.attn.hook_v(9)) with KL divergence 0.07201521843671799.
# Kept edge from N(blocks.1.hook_k_input(9)) to N(blocks.1.attn.hook_k(9)) with KL divergence 0.0558561272919178.
# Kept edge from N(blocks.1.hook_q_input(9)) to N(blocks.1.attn.hook_q(9)) with KL divergence 0.0558561272919178.
# Kept edge from N(blocks.1.hook_v_input(10)) to N(blocks.1.attn.hook_v(10)) with KL divergence 1.0158337354660034.
# Kept edge from N(blocks.1.hook_k_input(10)) to N(blocks.1.attn.hook_k(10)) with KL divergence 1.049993872642517.
# Kept edge from N(blocks.1.hook_q_input(10)) to N(blocks.1.attn.hook_q(10)) with KL divergence 1.049993872642517.
# Kept edge from N(blocks.1.hook_v_input(11)) to N(blocks.1.attn.hook_v(11)) with KL divergence 0.10880044847726822.
# Kept edge from N(blocks.1.hook_k_input(11)) to N(blocks.1.attn.hook_k(11)) with KL divergence 0.06918904185295105.
# Kept edge from N(blocks.1.hook_q_input(11)) to N(blocks.1.attn.hook_q(11)) with KL divergence 0.06918904185295105.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0036907712928950787.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0008632566314190626.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.001630560029298067.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0025861519388854504.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0011209659278392792.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.001295611378736794.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0023361744824796915.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0006702388054691255.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0036404679995030165.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0012536970898509026.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.0016486875247210264.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(0)) with KL divergence 0.001124432310461998.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(0)) with KL divergence 0.08778951317071915.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.001860455027781427.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.00028462742920964956.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.0012026821495965123.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.004914060700684786.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.00037135175080038607.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.0033405786380171776.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.0024190794210880995.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.00024262367514893413.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.0024921337608247995.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.00018454078235663474.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.0002505693701095879.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(0)) with KL divergence 0.00011104813165729865.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(0)) with KL divergence 0.02288649044930935.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.009042967110872269.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0014347787946462631.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.001386957592330873.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.00024272808514069766.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0018859077244997025.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0008572841179557145.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0006467658095061779.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.00035291677340865135.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.008795947767794132.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.00012469083594623953.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.0004872046411037445.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(0)) with KL divergence 0.00011617514246609062.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(0)) with KL divergence 0.008770454674959183.
# All in edges to N(blocks.1.hook_q_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.004669988062232733.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.002587399911135435.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0036749951541423798.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0037266938015818596.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.004613662138581276.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.002960182260721922.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.005285544320940971.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0034580575302243233.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.009167863056063652.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.002199488691985607.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0022840648889541626.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(1)) with KL divergence 0.0027222379576414824.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(1)) with KL divergence 0.031534355133771896.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.001091102370992303.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0001457348553230986.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0007256728131324053.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0039965142495930195.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.00025478110183030367.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0010114476317539811.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0003563067875802517.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(1)) with KL divergence 6.801535346312448e-05.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.0005149382050149143.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.00022361621086020023.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(1)) with KL divergence 0.00015179462207015604.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(1)) with KL divergence 5.2442399464780465e-05.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(1)) with KL divergence 0.010980484075844288.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.0008503886638209224.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.00015884028107393533.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.0002718718897085637.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.0001252774818567559.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.000762145034968853.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.00023703358601778746.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(1)) with KL divergence 8.292276470456272e-05.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(1)) with KL divergence 9.94091242318973e-05.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(1)) with KL divergence 0.0038483333773911.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(1)) with KL divergence 5.356927795219235e-05.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(1)) with KL divergence 6.238539208425209e-05.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(1)) with KL divergence 6.22635125182569e-05.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(1)) with KL divergence 0.002389205852523446.
# All in edges to N(blocks.1.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0015836834209039807.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.00048603463801555336.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0004302521701902151.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0021268439013510942.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0014158375561237335.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0005197934224270284.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0019195661880075932.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0004997454234398901.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.004606259521096945.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0008732270798645914.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.00040112726856023073.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(2)) with KL divergence 0.0003680115914903581.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(2)) with KL divergence 0.1017138808965683.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0022770888172090054.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.00038951635360717773.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0006927159265615046.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.005490951240062714.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.000628906418569386.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0004903879016637802.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.003232658142223954.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.00010489431588212028.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0017088598106056452.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0003753500641323626.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(2)) with KL divergence 0.0001694615202723071.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(2)) with KL divergence 8.123133738990873e-05.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(2)) with KL divergence 0.012858787551522255.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0038724818732589483.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.001090911915525794.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0029981667175889015.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(2)) with KL divergence 9.217716433340684e-05.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.003006831044331193.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0015668469714000821.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0003533392446115613.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.000366105989087373.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.023868674412369728.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0002224148774985224.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0003745559079106897.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0006041272426955402.
# Kept edge from N(hook_embed) to N(blocks.1.hook_q_input(2)) with KL divergence 0.0240822434425354.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0034746562596410513.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0015509636141359806.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0016392187681049109.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.002159073716029525.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.002195629058405757.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.001298978109844029.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0024070993531495333.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0017939555691555142.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.011619695462286472.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0015487687196582556.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.0028534140437841415.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(3)) with KL divergence 0.001409765100106597.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(3)) with KL divergence 0.024605276063084602.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0014863553224131465.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0008595488034188747.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0011173750972375274.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0026410860009491444.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0004777566355187446.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0006480271695181727.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.001325340592302382.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.00020159408450126648.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.00027444001170806587.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.00010533515160204843.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.0016875916626304388.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(3)) with KL divergence 0.00012513669207692146.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(3)) with KL divergence 0.005380694288760424.
# All in edges to N(blocks.1.hook_k_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(3)) with KL divergence 0.0.
# All in edges to N(blocks.1.hook_q_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)).
# Kept edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.03973553329706192.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.003916140645742416.
# Kept edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.014511603862047195.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.002599717816337943.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.030259951949119568.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.003697815118357539.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.005294746719300747.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.006525037344545126.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.03556118533015251.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.0019829063676297665.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.002940866630524397.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(4)) with KL divergence 0.0035007207188755274.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(4)) with KL divergence 0.6484737992286682.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.002690556924790144.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.009342190809547901.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.0015686624683439732.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.005793980322778225.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.9044596552848816.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.001675906591117382.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.0005046436563134193.
# Kept edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.17142318189144135.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.0005947884637862444.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.001112894737161696.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.004655525088310242.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(4)) with KL divergence 0.0023137424141168594.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(4)) with KL divergence 0.034730345010757446.
# Kept edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.042720746248960495.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.007207250222563744.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.007713824510574341.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.001514881500042975.
# Kept edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.039421383291482925.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.004682808183133602.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.0016375615959987044.
# Kept edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.04871915653347969.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.009279073216021061.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.0008945257286541164.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.0007070147548802197.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(4)) with KL divergence 0.0019418456358835101.
# Kept edge from N(hook_embed) to N(blocks.1.hook_q_input(4)) with KL divergence 0.8256236910820007.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.003934659995138645.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.001384159317240119.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0016427456866949797.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.004124211613088846.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0022896903101354837.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0023174460511654615.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.003350104670971632.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0016359522705897689.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.014451082795858383.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.003889600047841668.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0022623499389737844.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(5)) with KL divergence 0.0014594064559787512.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(5)) with KL divergence 0.12122200429439545.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0021842261776328087.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.00047567393630743027.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0007998965447768569.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0036767690908163786.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.00031932874117046595.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.001748802955262363.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0027026592288166285.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.00012595587759278715.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0033363362308591604.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.00044508432620204985.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.00047645330778323114.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(5)) with KL divergence 0.0001002728458843194.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(5)) with KL divergence 0.021826907992362976.
# Kept edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.013599557802081108.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0048390282317996025.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0022204050328582525.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0008091364870779216.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.003159436397254467.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0027102073654532433.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0004573254846036434.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0010036604944616556.
# Kept edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.02567468024790287.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0005532803479582071.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0006231339066289365.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(5)) with KL divergence 0.0017360517522320151.
# Kept edge from N(hook_embed) to N(blocks.1.hook_q_input(5)) with KL divergence 0.02158067747950554.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.006567709147930145.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0025482953060418367.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0028733336366713047.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0032654355745762587.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0037780485581606627.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0027710741851478815.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0019393459660932422.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0022187172435224056.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.008463606238365173.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0015041196020320058.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0015439882408827543.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(6)) with KL divergence 0.0015504660550504923.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(6)) with KL divergence 0.040621235966682434.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0021472659427672625.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0002539333363529295.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0012300469679757953.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.004122195765376091.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0010877145687118173.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0011661372845992446.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.001195417484268546.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0002354233874939382.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.001624508062377572.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0002940154809039086.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.0004512650484684855.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(6)) with KL divergence 0.00015251919103320688.
# Kept edge from N(hook_embed) to N(blocks.1.hook_k_input(6)) with KL divergence 0.01449026819318533.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.008026993833482265.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.001059240661561489.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.001994695980101824.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.00010314804967492819.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.0017765997909009457.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.0013290065107867122.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.0005678159068338573.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.000339290127158165.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.006664029322564602.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(6)) with KL divergence 3.733378980541602e-05.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(6)) with KL divergence 5.878231968381442e-05.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(6)) with KL divergence 0.00011090684711234644.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(6)) with KL divergence 0.0027176975272595882.
# All in edges to N(blocks.1.hook_q_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(6)) to N(blocks.1.attn.hook_q(6)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.007799056824296713.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.003145835595205426.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.002972204703837633.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0050751036033034325.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0041746352799236774.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.003975895699113607.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0065041277557611465.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.002409811597317457.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.007390711922198534.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.002771141240373254.
# Kept edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.019983183592557907.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(7)) with KL divergence 0.0025330600328743458.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(7)) with KL divergence 0.048683151602745056.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.001375048072077334.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0004901148495264351.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0008163321763277054.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0005664063501171768.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00044037235784344375.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0005633508553728461.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.000718718278221786.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00014021909737493843.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.00030003272695466876.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0001974158367374912.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.007756936363875866.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(7)) with KL divergence 0.0002181348972953856.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_k_input(7)) with KL divergence 0.006733877118676901.
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# Pruned edge from N(hook_embed) to N(blocks.1.hook_q_input(7)) with KL divergence 0.0.
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.004186183214187622.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.002781929913908243.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0018205468077212572.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.003464695531874895.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0020854168105870485.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0019109350396320224.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0033407583832740784.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0018108218209818006.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.009359646588563919.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0018685595132410526.
# Pruned edge from N(blocks.0.attn.hook_result(1)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0016888451064005494.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(8)) with KL divergence 0.0016810407396405935.
# Kept edge from N(hook_embed) to N(blocks.1.hook_v_input(8)) with KL divergence 0.02556684985756874.
# Pruned edge from N(blocks.0.attn.hook_result(11)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0012064991751685739.
# Pruned edge from N(blocks.0.attn.hook_result(10)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00019879861793015152.
# Pruned edge from N(blocks.0.attn.hook_result(9)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0005803623935207725.
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0015653359005227685.
# Pruned edge from N(blocks.0.attn.hook_result(7)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00018428520706947893.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.000626731722149998.
# Pruned edge from N(blocks.0.attn.hook_result(5)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0008816405897960067.
# Pruned edge from N(blocks.0.attn.hook_result(4)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00012326186697464436.
# Pruned edge from N(blocks.0.attn.hook_result(3)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.0006532216211780906.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(8)) with KL divergence 0.00011174894461873919.
# ...
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(8)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(6)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(2)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(2)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.0.attn.hook_result(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_resid_post).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(11)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(10)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(9)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(8)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(7)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(6)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(5)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(4)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(3)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(2)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(1)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_q_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_k_input(0)).
# Pruned edge from N(blocks.0.attn.hook_result(0)) to N(blocks.1.hook_v_input(0)).
# All in edges to N(blocks.1.hook_q_input(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(11)) to N(blocks.1.attn.hook_q(11)).
# All in edges to N(blocks.1.hook_k_input(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(11)) to N(blocks.1.attn.hook_k(11)).
# All in edges to N(blocks.1.hook_q_input(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(9)) to N(blocks.1.attn.hook_q(9)).
# All in edges to N(blocks.1.hook_k_input(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(9)) to N(blocks.1.attn.hook_k(9)).
# All in edges to N(blocks.1.hook_q_input(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(8)) to N(blocks.1.attn.hook_q(8)).
# All in edges to N(blocks.1.hook_k_input(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(8)) to N(blocks.1.attn.hook_k(8)).
# All in edges to N(blocks.1.hook_q_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(7)) to N(blocks.1.attn.hook_q(7)).
# All in edges to N(blocks.1.hook_k_input(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(7)) to N(blocks.1.attn.hook_k(7)).
# All in edges to N(blocks.1.hook_q_input(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(6)) to N(blocks.1.attn.hook_q(6)).
# All in edges to N(blocks.1.hook_q_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(3)) to N(blocks.1.attn.hook_q(3)).
# All in edges to N(blocks.1.hook_k_input(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_k_input(3)) to N(blocks.1.attn.hook_k(3)).
# All in edges to N(blocks.1.hook_q_input(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(1)) to N(blocks.1.attn.hook_q(1)).
# All in edges to N(blocks.1.hook_q_input(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.hook_q_input(0)) to N(blocks.1.attn.hook_q(0)).
# All in edges to N(blocks.1.attn.hook_q(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(11)) to N(blocks.1.attn.hook_result(11)).
# All in edges to N(blocks.1.attn.hook_k(11)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(11)) to N(blocks.1.attn.hook_result(11)).
# All in edges to N(blocks.1.attn.hook_q(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(9)) to N(blocks.1.attn.hook_result(9)).
# All in edges to N(blocks.1.attn.hook_k(9)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(9)) to N(blocks.1.attn.hook_result(9)).
# All in edges to N(blocks.1.attn.hook_q(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(8)) to N(blocks.1.attn.hook_result(8)).
# All in edges to N(blocks.1.attn.hook_k(8)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(8)) to N(blocks.1.attn.hook_result(8)).
# All in edges to N(blocks.1.attn.hook_q(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_k(7)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(7)) to N(blocks.1.attn.hook_result(7)).
# All in edges to N(blocks.1.attn.hook_q(6)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(6)) to N(blocks.1.attn.hook_result(6)).
# All in edges to N(blocks.1.attn.hook_q(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_k(3)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_k(3)) to N(blocks.1.attn.hook_result(3)).
# All in edges to N(blocks.1.attn.hook_q(1)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(1)) to N(blocks.1.attn.hook_result(1)).
# All in edges to N(blocks.1.attn.hook_q(0)) are not present, pruning all out edges.
# Pruned edge from N(blocks.1.attn.hook_q(0)) to N(blocks.1.attn.hook_result(0)).

# %%
edges_present = [data['present'] for _, _, data in graph.edges(data=True)]
nodes_present = [
    len(out_edges := graph.out_edges(node, data=True)) == 0
    or any(data['present'] for _, _, data in out_edges)
    for node in graph.nodes]

plt.figure(figsize=(12, 6))
pos = nx.multipartite_layout(graph)
nx.draw_networkx_nodes(
    graph,
    pos,
    node_size=50,
    alpha=[1 if present else 0.1 for present in nodes_present],
    node_color=["blue" if present else "red" for present in nodes_present])
nx.draw_networkx_edges(
    graph,
    pos,
    node_size=50,
    alpha=[0.5 if present else 0.1 for present in edges_present],
    edge_color=["black" if present else "red" for present in edges_present])
plt.show()

# %%
logits, cache = model.run_with_cache(dataset)
(dataset[:, seq_len] == logits[:, -1, :].argmax(-1)).float().mean().item()
# Out:
# 0.0
